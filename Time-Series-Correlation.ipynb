# %%
import pandas as pd 
import numpy as np

from sklearn import preprocessing

import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
# Out:
# Bad key "text.kerning_factor" on line 4 in
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\mpl-data\stylelib\_classic_test_patch.mplstyle.
# You probably need to get an updated matplotlibrc file from
# https://github.com/matplotlib/matplotlib/blob/v3.1.3/matplotlibrc.template
# or from the matplotlib source distribution

# %%
df = pd.read_csv('stocks/total_data_price_Change_Symbol.csv', index_col = 'Symbol')
df.head()
# Out:
#         2019-01-31  2019-02-01  2019-02-04  2019-02-05  2019-02-06  \
# Symbol
# A             0.92        0.82        0.19        0.09        0.09
# AAL          -0.26       -0.06        0.14        0.41        0.25
# AAP           1.44        1.21        0.77        0.75       -0.60
# AAPL          3.31        3.87        1.96        2.53        2.52
# ABBV          0.96        0.93       -0.16       -0.18       -0.43
#
#         2019-02-07  2019-02-08  2019-02-11  2019-02-12  2019-02-13  ...  \
# Symbol                                                              ...
# A            -0.23       -0.17       -0.07        0.57        0.48  ...
# AAL          -0.17       -0.31       -0.06       -0.14        0.07  ...
# AAP           0.59        0.32        2.63        1.58        1.34  ...
# AAPL         -0.10       -0.99       -1.33        0.22       -0.08  ...
# ABBV          0.20       -0.01        0.21        0.23        0.34  ...
#
#         2019-12-17  2019-12-18  2019-12-19  2019-12-20  2019-12-23  \
# Symbol
# A            -0.29       -0.09        0.02        0.41        0.61
# AAL           0.19        0.17        0.21        0.25        0.43
# AAP           0.62        0.94        1.01        0.07        0.66
# AAPL          2.97        1.52        0.05       -0.32        1.41
# ABBV          0.44        0.48       -0.21       -0.26        0.30
#
#         2019-12-24  2019-12-26  2019-12-27  2019-12-30  2019-12-31
# Symbol
# A             0.26        0.09        0.05       -0.07        0.01
# AAL           0.21        0.21       -0.29       -0.29       -0.33
# AAP           1.36        0.38       -0.54       -0.48        0.30
# AAPL          1.41        3.47        1.92        2.40        1.24
# ABBV          0.35        0.17       -0.34       -0.43       -0.42
#
# [5 rows x 232 columns]

# %%
def calculate_timeseries_correlation(data):
    result = []
    days = data.shape[1]
    len_symbols = data.shape[0]
    for i in range(len_symbols):
        symbol_corr = []
        for j in range(len_symbols):
            
            if i == j :
                symbol_corr.append(int(days / 2))
                continue
                
                
            change = [1 if np.sign(data[i , day]) == np.sign(data[j , day])
                      else 0 
                      for day in range(days)]

            symbol_corr.append(sum(change))

        result.append(symbol_corr)
    return result

# %%
symbols = df.index
data = df.to_numpy()
correlation = calculate_timeseries_correlation(data)

# %%
df_corr = pd.DataFrame(correlation, columns = symbols , index = symbols) 
df_corr.to_csv('symbols-correlation.csv')
df_corr.head()
# Out:
# Symbol    A  AAL  AAP  AAPL  ABBV  ABC  ABMD  ABT  ACN  ADBE  ...  XLNX  XOM  \
# Symbol                                                        ...
# A       116  141  128   160   152  140   142  160  166   154  ...   147  153
# AAL     141  116  137   146   144  129   125  134  136   140  ...   144  154
# AAP     128  137  116   139   147  122   124  126  134   127  ...   134  140
# AAPL    160  146  139   116   140  120   136  150  157   143  ...   153  156
# ABBV    152  144  147   140   116  141   158  155  163   143  ...   129  145
#
# Symbol  XRAY  XRX  XYL  YUM  ZBH  ZBRA  ZION  ZTS
# Symbol
# A        139  150  151  128  151   154   146  155
# AAL      117  154  146  113  135   132   153  135
# AAP      130  151  146  120  128   127   140  127
# AAPL     123  155  150  133  146   152   141  145
# ABBV     140  147  144  124  145   138   150  144
#
# [5 rows x 493 columns]

# %%
x = df_corr.values #returns a numpy array
min_max_scaler = preprocessing.MinMaxScaler(feature_range=(-1,1))
x_scaled = min_max_scaler.fit_transform(x)
df_normal = pd.DataFrame(x_scaled , columns = symbols , index = symbols)
df_normal.to_csv('symbols-correlation-normal.csv')
df_normal.head()
# Out:
# Symbol         A       AAL       AAP      AAPL      ABBV       ABC      ABMD  \
# Symbol
# A      -0.563218  0.186813 -0.135135  0.424658  0.600000  0.043478  0.441176
# AAL     0.011494 -0.362637  0.108108  0.041096  0.333333 -0.195652 -0.058824
# AAP    -0.287356  0.098901 -0.459459 -0.150685  0.433333 -0.347826 -0.088235
# AAPL    0.448276  0.296703  0.162162 -0.780822  0.200000 -0.391304  0.264706
# ABBV    0.264368  0.252747  0.378378 -0.123288 -0.600000  0.065217  0.911765
#
# Symbol       ABT       ACN      ADBE  ...      XLNX       XOM      XRAY  \
# Symbol                                ...
# A       0.333333  0.444444  0.194805  ...  0.333333  0.272727  0.400000
# AAL    -0.285714 -0.388889 -0.168831  ...  0.264368  0.292929 -0.333333
# AAP    -0.476190 -0.444444 -0.506494  ...  0.034483  0.010101  0.100000
# AAPL    0.095238  0.194444 -0.090909  ...  0.471264  0.333333 -0.133333
# ABBV    0.214286  0.361111 -0.090909  ... -0.080460  0.111111  0.433333
#
# Symbol       XRX       XYL       YUM       ZBH      ZBRA      ZION       ZTS
# Symbol
# A       0.382716  0.235955  0.047619  0.295775  0.500000  0.148936  0.512195
# AAL     0.481481  0.123596 -0.428571 -0.154930 -0.111111  0.297872  0.024390
# AAP     0.407407  0.123596 -0.206349 -0.352113 -0.250000  0.021277 -0.170732
# AAPL    0.506173  0.213483  0.206349  0.154930  0.444444  0.042553  0.268293
# ABBV    0.308642  0.078652 -0.079365  0.126761  0.055556  0.234043  0.243902
#
# [5 rows x 493 columns]

# %%
d_ = pd.read_csv('symbols-correlation-normal.csv', index_col = 'Symbol')
df_stack = d_.where(np.tril(np.ones(df_corr.shape) , k = -1).astype(np.bool))

df_stack = df_stack.stack().reset_index()
df_stack.columns =['Symbol_1', 'Symbol_2','Correlation']

df_stack.to_csv('symbols-correlation-stack.csv')
df_stack.head()
# Out:
#   Symbol_1 Symbol_2  Correlation
# 0      AAL        A     0.011494
# 1      AAP        A    -0.287356
# 2      AAP      AAL     0.098901
# 3     AAPL        A     0.448276
# 4     AAPL      AAL     0.296703

# %%
for col in df_normal.columns:
    print(col , df_normal[col].nlargest(3))
# Out:
# A Symbol
# TMO    1.000000
# PKI    0.954023
# WAT    0.954023
# Name: A, dtype: float64
# AAL Symbol
# FDX    1.000000
# UAL    1.000000
# DAL    0.978022
# Name: AAL, dtype: float64
# AAP Symbol
# GPC     1.000000
# CSCO    0.702703
# AZO     0.648649
# Name: AAP, dtype: float64
# AAPL Symbol
# KLAC    1.000000
# NVDA    0.863014
# APH     0.835616
# Name: AAPL, dtype: float64
# ABBV Symbol
# CTXS    1.0
# DGX     1.0
# FBHS    1.0
# Name: ABBV, dtype: float64
# ABC Symbol
# MCK    1.000000
# CAH    0.760870
# CVS    0.586957
# Name: ABC, dtype: float64
# ABMD Symbol
# MYL     1.000000
# MDT     0.970588
# ABBV    0.911765
# Name: ABMD, dtype: float64
# ABT Symbol
# SYK    1.000000
# TMO    0.642857
# MDT    0.619048
# Name: ABT, dtype: float64
# ACN Symbol
# MA      1.000000
# V       0.972222
# MSFT    0.916667
# Name: ACN, dtype: float64
# ADBE Symbol
# ANSS    1.000000
# NOW     1.000000
# ADSK    0.948052
# Name: ADBE, dtype: float64
# ADI Symbol
# MCHP    1.000000
# TXN     0.913978
# MXIM    0.870968
# Name: ADI, dtype: float64
# ADM Symbol
# FDX    1.000000
# C      0.946667
# LYB    0.946667
# Name: ADM, dtype: float64
# ADP Symbol
# PAYX    1.000000
# ANSS    0.942857
# INTU    0.942857
# Name: ADP, dtype: float64
# ADS Symbol
# ALB    1.000000
# PFG    0.927711
# UNM    0.927711
# Name: ADS, dtype: float64
# ADSK Symbol
# ADBE    1.000000
# NOW     0.763158
# ANSS    0.710526
# Name: ADSK, dtype: float64
# AEE Symbol
# LNT    1.000000
# CMS    0.960784
# XEL    0.960784
# Name: AEE, dtype: float64
# AEP Symbol
# CMS    1.000000
# XEL    1.000000
# WEC    0.981982
# Name: AEP, dtype: float64
# AES Symbol
# GPC    1.000000
# D      0.929825
# LNT    0.824561
# Name: AES, dtype: float64
# AFL Symbol
# HIG    1.000000
# AON    0.880597
# TRV    0.880597
# Name: AFL, dtype: float64
# AIG Symbol
# MET    1.000000
# AIZ    0.970149
# RE     0.970149
# Name: AIG, dtype: float64
# AIV Symbol
# UDR    1.000000
# MAA    0.936842
# AVB    0.915789
# Name: AIV, dtype: float64
# AIZ Symbol
# AIG    1.000000
# HIG    0.836066
# MMC    0.836066
# Name: AIZ, dtype: float64
# AJG Symbol
# AON     1.000000
# MMC     0.975610
# WLTW    0.780488
# Name: AJG, dtype: float64
# AKAM Symbol
# INFO    1.000000
# TWTR    0.838710
# CDW     0.774194
# Name: AKAM, dtype: float64
# ALB Symbol
# IBM    1.000000
# ADS    0.978022
# C      0.934066
# Name: ALB, dtype: float64
# ALGN Symbol
# IDXX    1.000000
# AMGN    0.934426
# AMD     0.901639
# Name: ALGN, dtype: float64
# ALK Symbol
# AAL     1.00000
# SIVB    0.97561
# FDX     0.95122
# Name: ALK, dtype: float64
# ALL Symbol
# HIG    1.000000
# PFG    0.936508
# NKE    0.904762
# Name: ALL, dtype: float64
# ALLE Symbol
# AME     1.000000
# BLK     0.904762
# FBHS    0.904762
# Name: ALLE, dtype: float64
# ALXN Symbol
# VAR     1.00000
# VRTX    1.00000
# REGN    0.90625
# Name: ALXN, dtype: float64
# AMAT Symbol
# LRCX    1.000000
# NVDA    0.827957
# KLAC    0.806452
# Name: AMAT, dtype: float64
# AMCR Symbol
# MTD     1.000000
# ADBE    0.719298
# HLT     0.719298
# Name: AMCR, dtype: float64
# AMD Symbol
# KLAC    1.000000
# MU      0.939394
# CDW     0.848485
# Name: AMD, dtype: float64
# AME Symbol
# ITW    1.000000
# FLS    0.958763
# EMR    0.938144
# Name: AME, dtype: float64
# AMGN Symbol
# MRK     1.000000
# ZTS     0.971014
# GILD    0.884058
# Name: AMGN, dtype: float64
# AMP Symbol
# DFS    1.000000
# LNC    0.892473
# URI    0.892473
# Name: AMP, dtype: float64
# AMT Symbol
# CCI     1.000000
# SBAC    0.798165
# PSA     0.761468
# Name: AMT, dtype: float64
# AMZN Symbol
# GOOGL    1.000000
# FB       0.971014
# GOOG     0.942029
# Name: AMZN, dtype: float64
# ANET Symbol
# CSCO    1.000000
# NSC     0.970588
# GLW     0.941176
# Name: ANET, dtype: float64
# ANSS Symbol
# ADBE    1.000000
# CDNS    0.898734
# NOW     0.873418
# Name: ANSS, dtype: float64
# ANTM Symbol
# UNH    1.000000
# CNC    0.797468
# HUM    0.645570
# Name: ANTM, dtype: float64
# AON Symbol
# AJG    1.000000
# MMC    0.780488
# HIG    0.682927
# Name: AON, dtype: float64
# AOS Symbol
# ETN     1.000000
# IPGP    1.000000
# EMN     0.930233
# Name: AOS, dtype: float64
# APA Symbol
# DVN    1.00
# EOG    0.88
# HP     0.80
# Name: APA, dtype: float64
# APD Symbol
# LIN    1.000000
# IEX    0.846154
# ECL    0.815385
# Name: APD, dtype: float64
# APH Symbol
# FTV    1.000000
# DOV    0.954023
# TEL    0.954023
# Name: APH, dtype: float64
# APTV Symbol
# GM     1.000000
# BWA    0.961165
# PH     0.864078
# Name: APTV, dtype: float64
# ARE Symbol
# DRE    1.000000
# BXP    0.893333
# UDR    0.893333
# Name: ARE, dtype: float64
# ATO Symbol
# AEE    1.000000
# LNT    1.000000
# CMS    0.918367
# Name: ATO, dtype: float64
# ATVI Symbol
# EA    1.000000
# MA    1.000000
# V     0.901639
# Name: ATVI, dtype: float64
# AVB Symbol
# EQR    1.000000
# UDR    0.960396
# PLD    0.841584
# Name: AVB, dtype: float64
# AVGO Symbol
# GM     1.000000
# FDX    0.911111
# SWK    0.911111
# Name: AVGO, dtype: float64
# AVY Symbol
# ETN    1.000000
# DOV    0.898734
# ITW    0.873418
# Name: AVY, dtype: float64
# AWK Symbol
# CMS    1.000000
# LNT    0.982609
# NEE    0.860870
# Name: AWK, dtype: float64
# AXP Symbol
# DFS     1.000000
# ADI     0.898734
# GOOG    0.822785
# Name: AXP, dtype: float64
# AZO Symbol
# ORLY    1.000000
# CMI     0.766234
# ADI     0.714286
# Name: AZO, dtype: float64
# BA Symbol
# LUV     1.000000
# PH      0.826087
# AMAT    0.797101
# Name: BA, dtype: float64
# BAC Symbol
# C       1.000000
# PNC     0.930435
# FITB    0.913043
# Name: BAC, dtype: float64
# BAX Symbol
# HOLX    1.000000
# ABT     0.914286
# EBAY    0.771429
# Name: BAX, dtype: float64
# BBY Symbol
# BLK    1.000000
# ITW    0.896104
# GS     0.870130
# Name: BBY, dtype: float64
# BDX Symbol
# ISRG    1.000000
# HOLX    0.967742
# BSX     0.935484
# Name: BDX, dtype: float64
# BEN Symbol
# LNC     1.000000
# PFG     0.890110
# TROW    0.868132
# Name: BEN, dtype: float64
# BIIB Symbol
# SIVB    1.000000
# COF     0.973684
# PH      0.973684
# Name: BIIB, dtype: float64
# BK Symbol
# NTRS    1.000000
# FITB    0.915789
# BLK     0.873684
# Name: BK, dtype: float64
# BKNG Symbol
# IPGP    1.000000
# APH     0.969231
# FLS     0.969231
# Name: BKNG, dtype: float64
# BKR Symbol
# FTI    1.000000
# SLB    0.866667
# XOM    0.840000
# Name: BKR, dtype: float64
# BLK Symbol
# URI    1.00
# COF    0.98
# C      0.92
# Name: BLK, dtype: float64
# BLL Symbol
# SYK     1.000000
# LDOS    0.852941
# TFX     0.823529
# Name: BLL, dtype: float64
# BMY Symbol
# PKI     1.000000
# MAS     0.961538
# FBHS    0.884615
# Name: BMY, dtype: float64
# BR Symbol
# V       1.000000
# JKHY    0.973684
# CTAS    0.947368
# Name: BR, dtype: float64
# BSX Symbol
# SYK    1.000000
# ABT    0.813333
# MDT    0.813333
# Name: BSX, dtype: float64
# BWA Symbol
# EMN     1.000000
# APTV    0.964602
# PH      0.964602
# Name: BWA, dtype: float64
# BXP Symbol
# VNO    1.000000
# SLG    0.674419
# REG    0.651163
# Name: BXP, dtype: float64
# C Symbol
# BAC    1.000000
# MS     0.924528
# JPM    0.886792
# Name: C, dtype: float64
# CAG Symbol
# K      1.000000
# GIS    0.671642
# CPB    0.522388
# Name: CAG, dtype: float64
# CAH Symbol
# CVS    1.000000
# MCK    0.977011
# ABC    0.862069
# Name: CAH, dtype: float64
# CAT Symbol
# EMR    1.000000
# ETN    0.933333
# PH     0.916667
# Name: CAT, dtype: float64
# CB Symbol
# CL      1.000000
# TRV     1.000000
# CINF    0.904762
# Name: CB, dtype: float64
# CBOE Symbol
# CME     1.000000
# ICE     0.862069
# MKTX    0.747126
# Name: CBOE, dtype: float64
# CBRE Symbol
# ETN    1.000000
# IEX    0.913043
# URI    0.884058
# Name: CBRE, dtype: float64
# CCI Symbol
# SBAC    1.000000
# AMT     0.898990
# EXR     0.818182
# Name: CCI, dtype: float64
# CCL Symbol
# NCLH    1.000000
# RCL     1.000000
# C       0.891304
# Name: CCL, dtype: float64
# CDNS Symbol
# SNPS    1.000000
# MA      0.866667
# ADBE    0.844444
# Name: CDNS, dtype: float64
# CDW Symbol
# ACN     1.0
# KLAC    1.0
# MCO     1.0
# Name: CDW, dtype: float64
# CE Symbol
# URI    1.000000
# SNA    0.917526
# ETN    0.876289
# Name: CE, dtype: float64
# CERN Symbol
# LH      1.000000
# GILD    0.965517
# ACN     0.896552
# Name: CERN, dtype: float64
# CF Symbol
# MOS    1.000000
# CMA    0.686747
# CAT    0.662651
# Name: CF, dtype: float64
# CFG Symbol
# FITB    1.000000
# BAC     0.963303
# KEY     0.963303
# Name: CFG, dtype: float64
# CHD Symbol
# CL     1.000000
# KMB    0.949367
# MKC    0.949367
# Name: CHD, dtype: float64
# CHRW Symbol
# EXPD    1.000000
# ODFL    0.873418
# AOS     0.822785
# Name: CHRW, dtype: float64
# CHTR Symbol
# CMCSA    1.000000
# GPN      1.000000
# AMZN     0.967742
# Name: CHTR, dtype: float64
# CI Symbol
# HUM    1.000000
# CVS    0.880952
# CNC    0.857143
# Name: CI, dtype: float64
# CINF Symbol
# CB     1.00000
# WRB    0.97561
# TRV    0.95122
# Name: CINF, dtype: float64
# CL Symbol
# PG    1.000000
# CB    0.955556
# WM    0.733333
# Name: CL, dtype: float64
# CLX Symbol
# KMB    1.000000
# KO     0.888889
# CB     0.861111
# Name: CLX, dtype: float64
# CMA Symbol
# CFG     1.000000
# ZION    1.000000
# MTB     0.980583
# Name: CMA, dtype: float64
# CMCSA Symbol
# OMC    1.000000
# NKE    0.873016
# ACN    0.841270
# Name: CMCSA, dtype: float64
# CME Symbol
# ICE     1.000000
# CBOE    0.650485
# NDAQ    0.572816
# Name: CME, dtype: float64
# CMG Symbol
# AMT     1.000000
# SBAC    1.000000
# TWTR    0.843137
# Name: CMG, dtype: float64
# CMI Symbol
# ITW     1.000000
# ETN     0.905660
# PCAR    0.886792
# Name: CMI, dtype: float64
# CMS Symbol
# LNT    1.000000
# XEL    0.923664
# AEP    0.862595
# Name: CMS, dtype: float64
# CNC Symbol
# UNH     1.000000
# HUM     0.842105
# ANTM    0.815789
# Name: CNC, dtype: float64
# CNP Symbol
# ATO    1.000000
# DTE    0.833333
# NI     0.833333
# Name: CNP, dtype: float64
# COF Symbol
# FITB    1.000000
# PNC     0.980769
# DFS     0.961538
# Name: COF, dtype: float64
# COG Symbol
# APA    1.0
# EOG    1.0
# HP     1.0
# Name: COG, dtype: float64
# COO Symbol
# SYK     1.00000
# TFX     0.87500
# ADBE    0.84375
# Name: COO, dtype: float64
# COP Symbol
# MRO    1.000000
# PXD    0.955056
# HES    0.932584
# Name: COP, dtype: float64
# COST Symbol
# TJX     1.000000
# ROST    0.890411
# LOW     0.726027
# Name: COST, dtype: float64
# COTY Symbol
# HBI     1.000000
# EXPD    0.857143
# PFG     0.821429
# Name: COTY, dtype: float64
# CPB Symbol
# K      1.000000
# CAG    0.938462
# SJM    0.846154
# Name: CPB, dtype: float64
# CPRT Symbol
# EBAY    1.000000
# MCO     0.945205
# VRSN    0.917808
# Name: CPRT, dtype: float64
# CRM Symbol
# NOW     1.000000
# INTU    0.944444
# ADBE    0.861111
# Name: CRM, dtype: float64
# CSCO Symbol
# FTV    1.000000
# ITW    0.922078
# PH     0.844156
# Name: CSCO, dtype: float64
# CSX Symbol
# PCAR    1.000000
# RTX     0.926829
# UNP     0.926829
# Name: CSX, dtype: float64
# CTAS Symbol
# ECL    1.00
# ZTS    1.00
# BR     0.92
# Name: CTAS, dtype: float64
# CTL Symbol
# BWA    1.000000
# IRM    0.932203
# WBA    0.932203
# Name: CTL, dtype: float64
# CTSH Symbol
# TROW    1.0000
# IBM     0.9375
# PCAR    0.9375
# Name: CTSH, dtype: float64
# CTXS Symbol
# TMO     1.000000
# MCO     0.968254
# ABBV    0.904762
# Name: CTXS, dtype: float64
# CVS Symbol
# CAH    1.000000
# CI     0.831325
# MCK    0.783133
# Name: CVS, dtype: float64
# CVX Symbol
# XOM    1.000000
# HP     0.772727
# MRO    0.750000
# Name: CVX, dtype: float64
# CXO Symbol
# EOG     1.000000
# DVN     0.864078
# FANG    0.864078
# Name: CXO, dtype: float64
# D Symbol
# DTE    1.000000
# AEP    0.975904
# CMS    0.951807
# Name: D, dtype: float64
# DAL Symbol
# UAL    1.000000
# AAL    0.883721
# GS     0.813953
# Name: DAL, dtype: float64
# DD Symbol
# BWA    1.00000
# LYB    1.00000
# CMI    0.93617
# Name: DD, dtype: float64
# DE Symbol
# CAT    1.000000
# ETN    0.895833
# AOS    0.833333
# Name: DE, dtype: float64
# DFS Symbol
# COF    1.000000
# MET    0.981481
# AMP    0.925926
# Name: DFS, dtype: float64
# DG Symbol
# ROST    1.000000
# DLTR    0.942029
# EFX     0.913043
# Name: DG, dtype: float64
# DGX Symbol
# LH      1.000
# ABBV    0.550
# DVA     0.525
# Name: DGX, dtype: float64
# DHI Symbol
# LEN    1.000000
# PHM    0.742574
# NVR    0.663366
# Name: DHI, dtype: float64
# DHR Symbol
# TMO    1.000000
# MRK    0.810811
# PKI    0.756757
# Name: DHR, dtype: float64
# DIS Symbol
# ACN     1.000000
# LKQ     0.882353
# TROW    0.823529
# Name: DIS, dtype: float64
# DISCA Symbol
# DISCK    1.000000
# OMC      0.050847
# VFC      0.016949
# Name: DISCA, dtype: float64
# DISCK Symbol
# DISCA    1.000000
# APTV     0.058824
# C        0.058824
# Name: DISCK, dtype: float64
# DISH Symbol
# HON      1.000000
# CMCSA    0.929825
# VFC      0.929825
# Name: DISH, dtype: float64
# DLR Symbol
# PEAK    1.000000
# FRT     0.831325
# EQIX    0.807229
# Name: DLR, dtype: float64
# DLTR Symbol
# DG     1.000000
# TJX    1.000000
# VFC    0.938462
# Name: DLTR, dtype: float64
# DOV Symbol
# ETN    1.000000
# CAT    0.980769
# APH    0.961538
# Name: DOV, dtype: float64
# DPZ Symbol
# RTX    1.000000
# ALK    0.846154
# HBI    0.807692
# Name: DPZ, dtype: float64
# DRE Symbol
# PLD    1.000000
# AVB    0.953488
# UDR    0.953488
# Name: DRE, dtype: float64
# DRI Symbol
# CLX     1.000000
# TROW    0.925926
# UHS     0.925926
# Name: DRI, dtype: float64
# DTE Symbol
# AEE    1.000000
# CMS    0.979167
# AEP    0.937500
# Name: DTE, dtype: float64
# DUK Symbol
# AEP    1.000000
# LNT    0.957895
# PNW    0.894737
# Name: DUK, dtype: float64
# DVA Symbol
# HCA    1.000000
# CI     0.894737
# DOV    0.815789
# Name: DVA, dtype: float64
# DVN Symbol
# EOG    1.000000
# XOM    0.721739
# PXD    0.686957
# Name: DVN, dtype: float64
# DXC Symbol
# TXT    1.000000
# IBM    0.949367
# BLK    0.924051
# Name: DXC, dtype: float64
# DXCM Symbol
# COO     1.000000
# JKHY    0.968254
# SYK     0.904762
# Name: DXCM, dtype: float64
# EA Symbol
# ATVI    1.000000
# ADSK    0.774194
# OKE     0.709677
# Name: EA, dtype: float64
# EBAY Symbol
# MCO     1.000000
# CPRT    0.863014
# BLK     0.835616
# Name: EBAY, dtype: float64
# ECL Symbol
# CTAS    1.000000
# IEX     0.970588
# APD     0.823529
# Name: ECL, dtype: float64
# ED Symbol
# NEE    1.000000
# AEP    0.979798
# ETR    0.979798
# Name: ED, dtype: float64
# EFX Symbol
# ACN    1.000000
# HD     0.890411
# MCO    0.863014
# Name: EFX, dtype: float64
# EIX Symbol
# SO     1.000000
# ATO    0.932203
# D      0.932203
# Name: EIX, dtype: float64
# EL Symbol
# CL      1.00000
# MDLZ    0.78125
# NKE     0.78125
# Name: EL, dtype: float64
# EMN Symbol
# BWA    1.000000
# GM     0.966667
# LYB    0.950000
# Name: EMN, dtype: float64
# EMR Symbol
# PH     1.000
# CAT    0.968
# ETN    0.968
# Name: EMR, dtype: float64
# EOG Symbol
# DVN    1.000000
# CXO    0.779661
# PXD    0.711864
# Name: EOG, dtype: float64
# EQIX Symbol
# CCI     1.000000
# DLR     0.924051
# SBAC    0.873418
# Name: EQIX, dtype: float64
# EQR Symbol
# UDR    1.000000
# AVB    0.981481
# ESS    0.925926
# Name: EQR, dtype: float64
# ES Symbol
# CMS    1.000000
# ED     0.940594
# LNT    0.940594
# Name: ES, dtype: float64
# ESS Symbol
# EQR    1.000000
# UDR    0.942308
# AVB    0.884615
# Name: ESS, dtype: float64
# ETFC Symbol
# MS      1.000000
# SCHW    1.000000
# BLK     0.912088
# Name: ETFC, dtype: float64
# ETN Symbol
# EMR    1.000000
# PH     0.964602
# CAT    0.929204
# Name: ETN, dtype: float64
# ETR Symbol
# CMS    1.000000
# AEP    0.961165
# LNT    0.961165
# Name: ETR, dtype: float64
# EVRG Symbol
# LNT    1.000000
# AEE    0.959596
# DTE    0.939394
# Name: EVRG, dtype: float64
# EW Symbol
# SYK    1.000000
# ZBH    0.916667
# MDT    0.888889
# Name: EW, dtype: float64
# EXC Symbol
# AEP     1.000000
# EVRG    1.000000
# DTE     0.975309
# Name: EXC, dtype: float64
# EXPD Symbol
# ODFL    1.000000
# TEL     0.958763
# LEG     0.896907
# Name: EXPD, dtype: float64
# EXPE Symbol
# BKNG    1.000000
# BK      0.680000
# AVGO    0.653333
# Name: EXPE, dtype: float64
# EXR Symbol
# PSA    1.000000
# CCI    0.956522
# ESS    0.869565
# Name: EXR, dtype: float64
# F Symbol
# BWA    1.000000
# SNA    1.000000
# URI    0.972973
# Name: F, dtype: float64
# FANG Symbol
# CXO    1.000000
# EOG    0.844444
# MRO    0.844444
# Name: FANG, dtype: float64
# FAST Symbol
# ITW    1.000000
# ETN    0.977011
# TEL    0.977011
# Name: FAST, dtype: float64
# FB Symbol
# AMZN    1.000000
# GOOG    0.717949
# ADSK    0.692308
# Name: FB, dtype: float64
# FBHS Symbol
# SNA    1.000000
# URI    1.000000
# BLK    0.909091
# Name: FBHS, dtype: float64
# FCX Symbol
# EMN    1.000000
# BWA    0.945946
# CAT    0.927928
# Name: FCX, dtype: float64
# FDX Symbol
# UPS     1.00
# SIVB    0.96
# C       0.94
# Name: FDX, dtype: float64
# FE Symbol
# CMS    1.00000
# NI     1.00000
# XEL    0.97561
# Name: FE, dtype: float64
# FFIV Symbol
# EMN    1.000000
# ITW    0.922330
# GLW    0.902913
# Name: FFIV, dtype: float64
# FIS Symbol
# FISV    1.000000
# MA      0.772152
# GPN     0.721519
# Name: FIS, dtype: float64
# FISV Symbol
# FIS    1.000000
# MDT    0.590909
# MA     0.568182
# Name: FISV, dtype: float64
# FITB Symbol
# PNC    1.000000
# BAC    0.964286
# CFG    0.964286
# Name: FITB, dtype: float64
# FLIR Symbol
# ROK    1.000000
# URI    0.945205
# BLK    0.917808
# Name: FLIR, dtype: float64
# FLS Symbol
# EMR    1.000000
# ETN    1.000000
# MMM    0.980392
# Name: FLS, dtype: float64
# FLT Symbol
# PYPL    1.000000
# ANSS    0.818182
# V       0.818182
# Name: FLT, dtype: float64
# FMC Symbol
# APTV    1.000000
# CE      0.977011
# PH      0.954023
# Name: FMC, dtype: float64
# FRC Symbol
# MTB    1.000000
# RF     1.000000
# BLK    0.977778
# Name: FRC, dtype: float64
# FRT Symbol
# REG    1.000000
# KIM    0.720430
# VNO    0.655914
# Name: FRT, dtype: float64
# FTI Symbol
# MRO    1.000
# EOG    0.975
# SLB    0.975
# Name: FTI, dtype: float64
# FTNT Symbol
# ADSK    1.000000
# ADBE    0.802817
# ANSS    0.802817
# Name: FTNT, dtype: float64
# FTV Symbol
# ITW    1.000000
# APH    0.956522
# MMM    0.891304
# Name: FTV, dtype: float64
# GD Symbol
# HII     1.000000
# TROW    0.826087
# RTX     0.739130
# Name: GD, dtype: float64
# GE Symbol
# HON    1.000000
# EMR    0.931034
# PPG    0.931034
# Name: GE, dtype: float64
# GILD Symbol
# OMC    1.000000
# PFG    1.000000
# MET    0.971831
# Name: GILD, dtype: float64
# GIS Symbol
# K       1.000000
# MDLZ    0.939394
# TRV     0.939394
# Name: GIS, dtype: float64
# GL Symbol
# MET    1.000000
# AMP    0.905882
# PRU    0.835294
# Name: GL, dtype: float64
# GLW Symbol
# APH    1.000000
# CAT    1.000000
# SWK    0.979381
# Name: GLW, dtype: float64
# GM Symbol
# APTV    1.000000
# EMN     0.964602
# BWA     0.823009
# Name: GM, dtype: float64
# GOOG Symbol
# GOOGL    1.000000
# MSFT     0.101695
# AMZN     0.067797
# Name: GOOG, dtype: float64
# GOOGL Symbol
# GOOG    1.000000
# AMZN    0.116667
# MSFT    0.083333
# Name: GOOGL, dtype: float64
# GPC Symbol
# GWW    1.000000
# APH    0.975610
# VFC    0.926829
# Name: GPC, dtype: float64
# GPN Symbol
# MA      1.000000
# V       0.922078
# PAYX    0.714286
# Name: GPN, dtype: float64
# GPS Symbol
# KSS    1.000000
# JWN    0.788235
# LB     0.741176
# Name: GPS, dtype: float64
# GRMN Symbol
# ANSS    1.0000
# AMGN    0.8125
# PH      0.8125
# Name: GRMN, dtype: float64
# GS Symbol
# MS     1.000000
# JPM    0.981308
# BAC    0.962617
# Name: GS, dtype: float64
# GWW Symbol
# GPC    1.000000
# VFC    0.978261
# ITW    0.913043
# Name: GWW, dtype: float64
# HAL Symbol
# SLB    1.000000
# HP     0.714286
# DVN    0.697479
# Name: HAL, dtype: float64
# HAS Symbol
# FDX    1.000000
# IFF    1.000000
# BLK    0.910448
# Name: HAS, dtype: float64
# HBAN Symbol
# RF      1.000000
# FITB    0.982609
# KEY     0.982609
# Name: HBAN, dtype: float64
# HBI Symbol
# LEG     1.000000
# EXPD    0.952941
# URI     0.905882
# Name: HBI, dtype: float64
# HCA Symbol
# DVA     1.000000
# NTRS    0.815789
# MS      0.789474
# Name: HCA, dtype: float64
# HD Symbol
# LOW    1.000000
# MMM    0.795455
# BLK    0.659091
# Name: HD, dtype: float64
# HES Symbol
# PXD    1.000000
# EOG    0.978723
# COP    0.893617
# Name: HES, dtype: float64
# HFC Symbol
# MPC    1.000000
# VLO    0.978723
# PSX    0.914894
# Name: HFC, dtype: float64
# HIG Symbol
# CB      1.000000
# AON     0.913043
# WLTW    0.913043
# Name: HIG, dtype: float64
# HII Symbol
# GD      1.000000
# RTX     0.901235
# TROW    0.728395
# Name: HII, dtype: float64
# HLT Symbol
# MAR    1.000000
# BLK    0.842105
# CCL    0.842105
# Name: HLT, dtype: float64
# HOG Symbol
# URI    1.000000
# CAT    0.959184
# PH     0.959184
# Name: HOG, dtype: float64
# HOLX Symbol
# BAX    1.000000
# TFX    0.861111
# BSX    0.777778
# Name: HOLX, dtype: float64
# HON Symbol
# PPG    1.000000
# BLK    0.910112
# ETN    0.820225
# Name: HON, dtype: float64
# HP Symbol
# EOG    1.000000
# HAL    0.978022
# SLB    0.868132
# Name: HP, dtype: float64
# HPE Symbol
# HPQ     1.000000
# CMI     0.980198
# NTAP    0.920792
# Name: HPE, dtype: float64
# HPQ Symbol
# HPE    1.000000
# CMI    0.804348
# EMR    0.782609
# Name: HPQ, dtype: float64
# HRB Symbol
# ALK    1.000000
# LEG    0.884615
# FDX    0.846154
# Name: HRB, dtype: float64
# HRL Symbol
# PEP    1.000000
# PG     0.894737
# HSY    0.859649
# Name: HRL, dtype: float64
# HSIC Symbol
# PPG    1.000000
# DVA    0.898305
# LH     0.898305
# Name: HSIC, dtype: float64
# HST Symbol
# MAR    1.000000
# IR     0.973333
# SWK    0.973333
# Name: HST, dtype: float64
# HSY Symbol
# MKC    1.000000
# WRB    0.870968
# CHD    0.806452
# Name: HSY, dtype: float64
# HUM Symbol
# UNH    1.000000
# CI     0.929412
# CNC    0.858824
# Name: HUM, dtype: float64
# IBM Symbol
# ITW    1.000000
# CMI    0.934066
# ALB    0.890110
# Name: IBM, dtype: float64
# ICE Symbol
# CME     1.000000
# NDAQ    0.917526
# AON     0.567010
# Name: ICE, dtype: float64
# IDXX Symbol
# ZTS    1.000000
# SYK    0.944444
# TFX    0.888889
# Name: IDXX, dtype: float64
# IEX Symbol
# AME    1.000
# ITW    0.925
# ECL    0.850
# Name: IEX, dtype: float64
# IFF Symbol
# HAS    1.000000
# URI    0.936508
# BLK    0.904762
# Name: IFF, dtype: float64
# ILMN Symbol
# DHR    1.000000
# PKI    0.969697
# IQV    0.939394
# Name: ILMN, dtype: float64
# INCY Symbol
# VRTX    1.000000
# AMGN    0.969697
# MRK     0.848485
# Name: INCY, dtype: float64
# INFO Symbol
# VRSK    1.000000
# MA      0.938462
# AON     0.907692
# Name: INFO, dtype: float64
# INTC Symbol
# ITW    1.000000
# APH    0.978947
# EMR    0.978947
# Name: INTC, dtype: float64
# INTU Symbol
# NOW     1.000000
# SNPS    0.974684
# PAYC    0.949367
# Name: INTU, dtype: float64
# IP Symbol
# WRK    1.000000
# PKG    0.912088
# RTX    0.692308
# Name: IP, dtype: float64
# IPG Symbol
# OMC    1.000000
# AMP    0.608696
# RTX    0.565217
# Name: IPG, dtype: float64
# IPGP Symbol
# TEL    1.000000
# EMN    0.907407
# AOS    0.851852
# Name: IPGP, dtype: float64
# IQV Symbol
# SYK     1.000000
# ANSS    0.907692
# BSX     0.876923
# Name: IQV, dtype: float64
# IR Symbol
# CMI    1.000000
# BAC    0.974684
# HLT    0.949367
# Name: IR, dtype: float64
# IRM Symbol
# REG    1.000000
# TAP    0.796610
# KHC    0.762712
# Name: IRM, dtype: float64
# ISRG Symbol
# VRSN    1.000000
# PYPL    0.911765
# BDX     0.823529
# Name: ISRG, dtype: float64
# IT Symbol
# MSFT    1.000000
# ACN     0.971014
# TROW    0.942029
# Name: IT, dtype: float64
# ITW Symbol
# PH     1.000000
# CMI    0.904762
# EMR    0.904762
# Name: ITW, dtype: float64
# IVZ Symbol
# PRU    1.000000
# PFG    0.869565
# LNC    0.826087
# Name: IVZ, dtype: float64
# J Symbol
# CAT    1.000000
# FLS    0.977528
# ETN    0.932584
# Name: J, dtype: float64
# JBHT Symbol
# EXPD    1.000000
# MHK     0.911765
# LEG     0.882353
# Name: JBHT, dtype: float64
# JCI Symbol
# DOV    1.000000
# PPG    0.850746
# ETN    0.820896
# Name: JCI, dtype: float64
# JKHY Symbol
# BR      1.000000
# ACN     0.923077
# MSCI    0.923077
# Name: JKHY, dtype: float64
# JNJ Symbol
# MRK    1.0
# HAS    0.8
# LLY    0.8
# Name: JNJ, dtype: float64
# JNPR Symbol
# XRX     1.000000
# NVDA    0.972973
# PCAR    0.972973
# Name: JNPR, dtype: float64
# JPM Symbol
# C      1.00
# BAC    0.98
# GS     0.96
# Name: JPM, dtype: float64
# JWN Symbol
# KSS    1.000000
# GPS    0.890411
# RL     0.890411
# Name: JWN, dtype: float64
# K Symbol
# CAG    1.000000
# GIS    0.777778
# CPB    0.611111
# Name: K, dtype: float64
# KEY Symbol
# CFG     1.000000
# FITB    0.981132
# PNC     0.943396
# Name: KEY, dtype: float64
# KEYS Symbol
# HON    1.000000
# IEX    1.000000
# APH    0.944444
# Name: KEYS, dtype: float64
# KHC Symbol
# BWA    1.000000
# DVN    0.818182
# IRM    0.818182
# Name: KHC, dtype: float64
# KIM Symbol
# REG    1.000000
# FRT    0.951807
# SPG    0.638554
# Name: KIM, dtype: float64
# KLAC Symbol
# LRCX    1.00
# AAPL    0.92
# AMAT    0.92
# Name: KLAC, dtype: float64
# KMB Symbol
# PG     1.0
# CL     0.9
# CHD    0.8
# Name: KMB, dtype: float64
# KMI Symbol
# OKE    1.000000
# WMB    0.815385
# CVX    0.784615
# Name: KMI, dtype: float64
# KMX Symbol
# PRU     1.000000
# FITB    0.965517
# PBCT    0.931034
# Name: KMX, dtype: float64
# KO Symbol
# PEP    1.000000
# CLX    0.844156
# WM     0.844156
# Name: KO, dtype: float64
# KR Symbol
# URI    1.000000
# ADM    0.961538
# MET    0.961538
# Name: KR, dtype: float64
# KSS Symbol
# GPS    1.000000
# JWN    0.883721
# CCL    0.813953
# Name: KSS, dtype: float64
# KSU Symbol
# APH    1.0
# DOV    1.0
# NSC    1.0
# Name: KSU, dtype: float64
# L Symbol
# BLK    1.000000
# PFG    0.971831
# TAP    0.915493
# Name: L, dtype: float64
# LB Symbol
# GPS    1.000000
# BEN    0.848101
# TXT    0.848101
# Name: LB, dtype: float64
# LDOS Symbol
# MA      1.000000
# PAYC    1.000000
# LMT     0.940299
# Name: LDOS, dtype: float64
# LEG Symbol
# EMN     1.000000
# ETN     1.000000
# APTV    0.978723
# Name: LEG, dtype: float64
# LEN Symbol
# PHM    1.000000
# DHI    0.916667
# NVR    0.479167
# Name: LEN, dtype: float64
# LH Symbol
# DGX     1.000000
# PFE     0.605263
# CERN    0.552632
# Name: LH, dtype: float64
# LHX Symbol
# NOC     1.000000
# LMT     0.909091
# LDOS    0.659091
# Name: LHX, dtype: float64
# LIN Symbol
# APD    1.00
# PPG    0.84
# SHW    0.84
# Name: LIN, dtype: float64
# LKQ Symbol
# TEL    1.000000
# APH    0.975309
# CE     0.975309
# Name: LKQ, dtype: float64
# LLY Symbol
# MRK    1.000000
# ZTS    0.850746
# A      0.731343
# Name: LLY, dtype: float64
# LMT Symbol
# NOC     1.000000
# LDOS    0.514563
# LHX     0.436893
# Name: LMT, dtype: float64
# LNC Symbol
# PBCT    1.000000
# DFS     0.941176
# PRU     0.941176
# Name: LNC, dtype: float64
# LNT Symbol
# CMS    1.000000
# WEC    0.825397
# XEL    0.825397
# Name: LNT, dtype: float64
# LOW Symbol
# HD     1.000
# TJX    0.800
# GPC    0.775
# Name: LOW, dtype: float64
# LRCX Symbol
# AMAT    1.000000
# KLAC    0.848101
# MU      0.848101
# Name: LRCX, dtype: float64
# LUV Symbol
# UAL     1.000000
# BA      0.763158
# TROW    0.763158
# Name: LUV, dtype: float64
# LVS Symbol
# WYNN    1.000000
# EMN     0.852632
# ITW     0.831579
# Name: LVS, dtype: float64
# LW Symbol
# LDOS    1.000000
# MKC     1.000000
# CPB     0.962264
# Name: LW, dtype: float64
# LYB Symbol
# EMN    1.000000
# URI    0.847619
# BWA    0.809524
# Name: LYB, dtype: float64
# LYV Symbol
# ANSS    1.000000
# LDOS    0.820896
# TDG     0.820896
# Name: LYV, dtype: float64
# MA Symbol
# V       1.000000
# PAYX    0.588235
# ACN     0.549020
# Name: MA, dtype: float64
# MAA Symbol
# AIV    1.00
# PLD    1.00
# EQR    0.98
# Name: MAA, dtype: float64
# MAR Symbol
# HLT    1.000000
# CCL    0.887640
# BLK    0.842697
# Name: MAR, dtype: float64
# MAS Symbol
# DOV     1.000000
# SWK     0.951807
# FBHS    0.855422
# Name: MAS, dtype: float64
# MCD Symbol
# CB      1.000000
# MKTX    1.000000
# HIG     0.866667
# Name: MCD, dtype: float64
# MCHP Symbol
# MXIM    1.000000
# ADI     0.959596
# TXN     0.959596
# Name: MCHP, dtype: float64
# MCK Symbol
# ABC    1.000000
# CAH    0.863636
# CVS    0.681818
# Name: MCK, dtype: float64
# MCO Symbol
# SPGI    1.000000
# VRSN    0.785714
# MSFT    0.738095
# Name: MCO, dtype: float64
# MDLZ Symbol
# CL     1.000000
# CB     0.942029
# KMB    0.913043
# Name: MDLZ, dtype: float64
# MDT Symbol
# SYK    1.000000
# ABT    0.741176
# BSX    0.694118
# Name: MDT, dtype: float64
# MET Symbol
# DFS    1.000000
# GL     0.882353
# LNC    0.862745
# Name: MET, dtype: float64
# MGM Symbol
# URI     1.000000
# CCL     0.952941
# WYNN    0.929412
# Name: MGM, dtype: float64
# MHK Symbol
# WHR     1.000000
# PCAR    0.950617
# SWK     0.950617
# Name: MHK, dtype: float64
# MKC Symbol
# CHD     1.00000
# HSY     1.00000
# LDOS    0.74359
# Name: MKC, dtype: float64
# MKTX Symbol
# MA     1.000000
# GPN    0.918919
# WM     0.918919
# Name: MKTX, dtype: float64
# MLM Symbol
# VMC     1.000000
# LDOS    0.333333
# EFX     0.310345
# Name: MLM, dtype: float64
# MMC Symbol
# AJG     1.000000
# WLTW    0.894737
# AON     0.789474
# Name: MMC, dtype: float64
# MMM Symbol
# FLS    1.000000
# ROK    0.961538
# ETN    0.942308
# Name: MMM, dtype: float64
# MNST Symbol
# EL     1.000000
# NSC    0.925926
# GPN    0.888889
# Name: MNST, dtype: float64
# MO Symbol
# PM      1.0
# VAR     1.0
# ALGN    0.8
# Name: MO, dtype: float64
# MOS Symbol
# CAT    1.000000
# CF     0.958763
# EMN    0.958763
# Name: MOS, dtype: float64
# MPC Symbol
# HFC    1.000000
# VLO    0.887640
# PSX    0.865169
# Name: MPC, dtype: float64
# MRK Symbol
# DHR    1.000000
# ZTS    1.000000
# TFX    0.972973
# Name: MRK, dtype: float64
# MRO Symbol
# EOG    1.000000
# NBL    0.980198
# DVN    0.920792
# Name: MRO, dtype: float64
# MS Symbol
# C      1.000000
# BAC    0.962963
# GS     0.944444
# Name: MS, dtype: float64
# MSCI Symbol
# SPGI    1.000000
# V       0.837209
# MA      0.767442
# Name: MSCI, dtype: float64
# MSFT Symbol
# V      1.000000
# MA     0.831325
# ACN    0.783133
# Name: MSFT, dtype: float64
# MSI Symbol
# LMT    1.000000
# MMC    1.000000
# EFX    0.949367
# Name: MSI, dtype: float64
# MTB Symbol
# PNC    1.000000
# KEY    0.881188
# C      0.861386
# Name: MTB, dtype: float64
# MTD Symbol
# TMO    1.000000
# PKI    0.914286
# APH    0.828571
# Name: MTD, dtype: float64
# MU Symbol
# WDC     1.000000
# LRCX    0.862745
# NVDA    0.803922
# Name: MU, dtype: float64
# MXIM Symbol
# TXN     1.000000
# MCHP    0.978495
# ADI     0.806452
# Name: MXIM, dtype: float64
# MYL Symbol
# DOV     1.000000
# PRGO    0.973333
# A       0.946667
# Name: MYL, dtype: float64
# NBL Symbol
# MRO    1.000000
# DVN    0.943396
# EOG    0.924528
# Name: NBL, dtype: float64
# NCLH Symbol
# RCL    1.000000
# CCL    0.956044
# ITW    0.846154
# Name: NCLH, dtype: float64
# NDAQ Symbol
# ICE    1.000000
# MA     0.701149
# CME    0.586207
# Name: NDAQ, dtype: float64
# NEE Symbol
# LNT    1.000000
# CMS    0.964602
# AEP    0.929204
# Name: NEE, dtype: float64
# NEM Symbol
# SRE    1.000000
# AEP    0.909091
# XEL    0.878788
# Name: NEM, dtype: float64
# NFLX Symbol
# ORCL    1.000000
# AMD     0.966667
# HLT     0.933333
# Name: NFLX, dtype: float64
# NI Symbol
# DTE    1.000000
# FE     0.929412
# AEE    0.858824
# Name: NI, dtype: float64
# NKE Symbol
# VFC    1.00000
# HIG    0.96875
# ACN    0.90625
# Name: NKE, dtype: float64
# NLSN Symbol
# NWSA    1.000000
# FDX     0.932203
# ZION    0.932203
# Name: NLSN, dtype: float64
# NOC Symbol
# LMT     1.000000
# LHX     0.532710
# LDOS    0.495327
# Name: NOC, dtype: float64
# NOV Symbol
# SLB    1.000000
# HAL    0.937500
# HP     0.854167
# Name: NOV, dtype: float64
# NOW Symbol
# PAYC    1.000000
# ADBE    0.810526
# ANSS    0.705263
# Name: NOW, dtype: float64
# NRG Symbol
# ATO    1.000000
# ED     0.962963
# D      0.777778
# Name: NRG, dtype: float64
# NSC Symbol
# UNP    1.000000
# CSX    0.853659
# RTX    0.780488
# Name: NSC, dtype: float64
# NTAP Symbol
# TROW    1.000000
# HPE     0.953488
# LKQ     0.906977
# Name: NTAP, dtype: float64
# NTRS Symbol
# BAC    1.000000
# KEY    0.959184
# BK     0.918367
# Name: NTRS, dtype: float64
# NUE Symbol
# EMN    1.000000
# CAT    0.978723
# ETN    0.978723
# Name: NUE, dtype: float64
# NVDA Symbol
# AMAT    1.000000
# ETN     0.977528
# MU      0.977528
# Name: NVDA, dtype: float64
# NVR Symbol
# DHI    1.000000
# LEN    0.880597
# PHM    0.791045
# Name: NVR, dtype: float64
# NWL Symbol
# DOV    1.000000
# WRK    0.921053
# NUE    0.842105
# Name: NWL, dtype: float64
# NWS Symbol
# NWSA    1.000000
# TEL     0.333333
# APTV    0.282051
# Name: NWS, dtype: float64
# NWSA Symbol
# NWS     1.000000
# APTV    0.357798
# BWA     0.357798
# Name: NWSA, dtype: float64
# O Symbol
# EQR    1.000000
# ESS    0.959596
# UDR    0.959596
# Name: O, dtype: float64
# ODFL Symbol
# EXPD    1.00000
# APH     0.78022
# LEG     0.78022
# Name: ODFL, dtype: float64
# OKE Symbol
# WMB    1.000000
# DVN    0.820225
# EOG    0.707865
# Name: OKE, dtype: float64
# OMC Symbol
# IPG      1.000000
# INTC     0.623529
# CMCSA    0.600000
# Name: OMC, dtype: float64
# ORCL Symbol
# IBM     1.000000
# INTC    0.921053
# UNM     0.921053
# Name: ORCL, dtype: float64
# ORLY Symbol
# AZO    1.000
# GPC    0.575
# ROL    0.550
# Name: ORLY, dtype: float64
# OXY Symbol
# DVN    1.000000
# EOG    0.953488
# MRO    0.883721
# Name: OXY, dtype: float64
# PAYC Symbol
# NOW     1.000000
# ADBE    0.723404
# INTU    0.659574
# Name: PAYC, dtype: float64
# PAYX Symbol
# MA     1.00
# V      0.85
# ADP    0.75
# Name: PAYX, dtype: float64
# PBCT Symbol
# RF      1.000000
# LNC     0.942857
# FITB    0.923810
# Name: PBCT, dtype: float64
# PCAR Symbol
# ITW    1.000000
# BWA    0.938776
# ROK    0.938776
# Name: PCAR, dtype: float64
# PEAK Symbol
# VTR     1.000000
# WELL    0.889908
# O       0.834862
# Name: PEAK, dtype: float64
# PEG Symbol
# SRE    1.000000
# XEL    0.931818
# WEC    0.909091
# Name: PEG, dtype: float64
# PEP Symbol
# PG    1.000000
# CL    0.945205
# KO    0.890411
# Name: PEP, dtype: float64
# PFE Symbol
# TMO    1.000000
# LH     0.820896
# PKI    0.820896
# Name: PFE, dtype: float64
# PFG Symbol
# DFS    1.000000
# LNC    0.956044
# BLK    0.934066
# Name: PFG, dtype: float64
# PG Symbol
# CL     1.000000
# KMB    0.788235
# PEP    0.741176
# Name: PG, dtype: float64
# PGR Symbol
# CB     1.00000
# MA     0.93750
# AJG    0.90625
# Name: PGR, dtype: float64
# PH Symbol
# EMR    1.000000
# URI    1.000000
# ITW    0.984127
# Name: PH, dtype: float64
# PHM Symbol
# LEN    1.000000
# DHI    0.609195
# NVR    0.356322
# Name: PHM, dtype: float64
# PKG Symbol
# WRK     1.000000
# IP      0.950617
# NTRS    0.679012
# Name: PKG, dtype: float64
# PKI Symbol
# TMO    1.000000
# A      0.883721
# DOV    0.744186
# Name: PKI, dtype: float64
# PLD Symbol
# AVB    1.000000
# MAA    1.000000
# DRE    0.831325
# Name: PLD, dtype: float64
# PM Symbol
# MO     1.000000
# VZ     1.000000
# APH    0.928571
# Name: PM, dtype: float64
# PNC Symbol
# FITB    1.000000
# BAC     0.980769
# COF     0.942308
# Name: PNC, dtype: float64
# PNR Symbol
# ITW    1.000000
# RTX    0.958763
# PH     0.938144
# Name: PNR, dtype: float64
# PNW Symbol
# AEP    1.00
# LNT    1.00
# WEC    0.98
# Name: PNW, dtype: float64
# PPG Symbol
# HON    1.000000
# ITW    0.831579
# DOV    0.789474
# Name: PPG, dtype: float64
# PPL Symbol
# AEP    1.000000
# PEG    0.862069
# FE     0.827586
# Name: PPL, dtype: float64
# PRGO Symbol
# RF      1.000000
# MYL     0.891892
# NTRS    0.864865
# Name: PRGO, dtype: float64
# PRU Symbol
# LNC    1.000000
# MET    0.939394
# COF    0.898990
# Name: PRU, dtype: float64
# PSA Symbol
# EXR    1.000000
# AWK    0.813084
# AMT    0.794393
# Name: PSA, dtype: float64
# PSX Symbol
# HFC    1.000000
# VLO    1.000000
# MPC    0.953488
# Name: PSX, dtype: float64
# PVH Symbol
# EMN     1.000000
# ROK     0.956044
# IPGP    0.934066
# Name: PVH, dtype: float64
# PWR Symbol
# XYL    1.000000
# SWK    0.880952
# URI    0.880952
# Name: PWR, dtype: float64
# PXD Symbol
# EOG    1.000000
# DVN    0.979798
# XOM    0.959596
# Name: PXD, dtype: float64
# PYPL Symbol
# FLT    1.000000
# V      1.000000
# MA     0.924051
# Name: PYPL, dtype: float64
# QCOM Symbol
# KLAC    1.000000
# AMAT    0.972973
# ETN     0.918919
# Name: QCOM, dtype: float64
# QRVO Symbol
# MU      1.000000
# SWKS    1.000000
# NVDA    0.931034
# Name: QRVO, dtype: float64
# RCL Symbol
# NCLH    1.000000
# CCL     0.958333
# SIVB    0.708333
# Name: RCL, dtype: float64
# RE Symbol
# HIG    1.000000
# WRB    0.794118
# AIG    0.705882
# Name: RE, dtype: float64
# REG Symbol
# FRT    1.000000
# KIM    0.770833
# BXP    0.583333
# Name: REG, dtype: float64
# REGN Symbol
# ALXN    1.000000
# AMGN    0.970149
# VRTX    0.940299
# Name: REGN, dtype: float64
# RF Symbol
# PBCT    1.000000
# FITB    0.962963
# CFG     0.925926
# Name: RF, dtype: float64
# RHI Symbol
# APH    1.000000
# BLK    0.977011
# XYL    0.977011
# Name: RHI, dtype: float64
# RJF Symbol
# LNC     1.000000
# ETFC    0.938776
# PRU     0.938776
# Name: RJF, dtype: float64
# RL Symbol
# PH     1.000000
# CAT    0.959184
# URI    0.938776
# Name: RL, dtype: float64
# RMD Symbol
# TFX    1.000000
# MDT    0.947368
# ABT    0.921053
# Name: RMD, dtype: float64
# ROK Symbol
# ITW    1.000000
# PH     1.000000
# ETN    0.980769
# Name: ROK, dtype: float64
# ROL Symbol
# AZO     1.000000
# CSX     0.971831
# ORLY    0.971831
# Name: ROL, dtype: float64
# ROP Symbol
# ADBE    1.0
# AME     1.0
# HON     1.0
# Name: ROP, dtype: float64
# ROST Symbol
# TJX    1.000000
# NKE    0.808219
# LOW    0.726027
# Name: ROST, dtype: float64
# RSG Symbol
# WM      1.000000
# VRSK    0.714286
# MRK     0.666667
# Name: RSG, dtype: float64
# RTX Symbol
# PNR     1.000000
# CSX     0.898734
# PCAR    0.898734
# Name: RTX, dtype: float64
# SBAC Symbol
# CCI    1.000000
# AMT    0.663158
# AVB    0.578947
# Name: SBAC, dtype: float64
# SBUX Symbol
# SYK     1.000000
# WLTW    0.966102
# CDNS    0.932203
# Name: SBUX, dtype: float64
# SCHW Symbol
# ETFC    1.00
# AMP     0.84
# COF     0.84
# Name: SCHW, dtype: float64
# SEE Symbol
# AVY    1.000000
# PKG    0.803279
# PKI    0.770492
# Name: SEE, dtype: float64
# SHW Symbol
# ODFL    1.000000
# HON     0.974359
# CTAS    0.948718
# Name: SHW, dtype: float64
# SIVB Symbol
# CFG     1.000000
# PNC     0.981818
# FITB    0.945455
# Name: SIVB, dtype: float64
# SJM Symbol
# KMB     1.000000
# CPB     0.781818
# MDLZ    0.745455
# Name: SJM, dtype: float64
# SLB Symbol
# HAL    1.000000
# DVN    0.785124
# EOG    0.735537
# Name: SLB, dtype: float64
# SLG Symbol
# VNO    1.000000
# BXP    0.792208
# FRT    0.428571
# Name: SLG, dtype: float64
# SNA Symbol
# URI    1.00
# ETN    0.92
# EMR    0.90
# Name: SNA, dtype: float64
# SNPS Symbol
# CDNS    1.000000
# MA      0.853659
# INTU    0.780488
# Name: SNPS, dtype: float64
# SO Symbol
# CMS    1.000000
# LNT    0.963636
# XEL    0.945455
# Name: SO, dtype: float64
# SPG Symbol
# FRT    1.0
# REG    1.0
# BXP    0.9
# Name: SPG, dtype: float64
# SPGI Symbol
# MCO     1.000000
# MSCI    0.847826
# VRSN    0.826087
# Name: SPGI, dtype: float64
# SRE Symbol
# PEG    1.000000
# XEL    0.879518
# AEP    0.855422
# Name: SRE, dtype: float64
# STE Symbol
# SYK    1.000000
# COO    0.761194
# ABT    0.641791
# Name: STE, dtype: float64
# STT Symbol
# GS     1.00
# MS     0.96
# DFS    0.94
# Name: STT, dtype: float64
# STX Symbol
# CMI    1.000000
# GM     0.925926
# HPE    0.925926
# Name: STX, dtype: float64
# STZ Symbol
# BR      1.000000
# AKAM    0.877551
# TAP     0.877551
# Name: STZ, dtype: float64
# SWK Symbol
# ITW    1.000000
# CMI    0.978261
# DOV    0.956522
# Name: SWK, dtype: float64
# SWKS Symbol
# MCHP    1.000000
# MXIM    0.844444
# QRVO    0.777778
# Name: SWKS, dtype: float64
# SYF Symbol
# DFS     1.000000
# LNC     0.948052
# TROW    0.896104
# Name: SYF, dtype: float64
# SYK Symbol
# ABT    1.000000
# MDT    0.873418
# BSX    0.721519
# Name: SYK, dtype: float64
# SYY Symbol
# VZ     1.000000
# NKE    0.962264
# PG     0.962264
# Name: SYY, dtype: float64
# T Symbol
# TMUS    1.000000
# ACN     0.803279
# HPE     0.770492
# Name: T, dtype: float64
# TAP Symbol
# L      1.000000
# PFG    0.870130
# HOG    0.688312
# Name: TAP, dtype: float64
# TDG Symbol
# RTX    1.000000
# V      1.000000
# AON    0.972222
# Name: TDG, dtype: float64
# TEL Symbol
# IPGP    1.000000
# APH     0.957447
# EXPD    0.936170
# Name: TEL, dtype: float64
# TFC Symbol
# MTB     1.000000
# FITB    0.978261
# BAC     0.913043
# Name: TFC, dtype: float64
# TFX Symbol
# SYK     1.000000
# MRK     0.896104
# IDXX    0.844156
# Name: TFX, dtype: float64
# TGT Symbol
# MMM    1.000000
# DG     0.907692
# VFC    0.907692
# Name: TGT, dtype: float64
# TIF Symbol
# RHI    1.000000
# BLK    0.949367
# LVS    0.898734
# Name: TIF, dtype: float64
# TJX Symbol
# ROST    1.000000
# LOW     0.974026
# COST    0.766234
# Name: TJX, dtype: float64
# TMO Symbol
# PKI    1.000000
# A      0.924051
# DHR    0.822785
# Name: TMO, dtype: float64
# TMUS Symbol
# T      1.000000
# VZ     0.824561
# GPC    0.789474
# Name: TMUS, dtype: float64
# TPR Symbol
# PH     1.000000
# ITW    0.978022
# PNR    0.912088
# Name: TPR, dtype: float64
# TROW Symbol
# BLK     1.000000
# COF     0.934066
# NTAP    0.934066
# Name: TROW, dtype: float64
# TRV Symbol
# CB      1.000000
# CINF    0.844156
# HIG     0.688312
# Name: TRV, dtype: float64
# TSCO Symbol
# CPRT    1.000000
# UNP     0.966667
# DFS     0.933333
# Name: TSCO, dtype: float64
# TSN Symbol
# APD    1.000000
# BLL    0.964286
# MA     0.928571
# Name: TSN, dtype: float64
# TTWO Symbol
# SNPS    1.000000
# CCI     0.964912
# FIS     0.894737
# Name: TTWO, dtype: float64
# TWTR Symbol
# VRSN    1.000000
# ZTS     0.876923
# AMZN    0.784615
# Name: TWTR, dtype: float64
# TXN Symbol
# MXIM    1.000000
# MCHP    0.934066
# ADI     0.846154
# Name: TXN, dtype: float64
# TXT Symbol
# MMM    1.000000
# PH     0.956044
# BWA    0.934066
# Name: TXT, dtype: float64
# UA Symbol
# UAA    1.000000
# AMP    0.135593
# BAC    0.118644
# Name: UA, dtype: float64
# UAA Symbol
# UA     1.000000
# AMP    0.235772
# BAC    0.219512
# Name: UAA, dtype: float64
# UAL Symbol
# DAL    1.000000
# AAL    0.906977
# LEG    0.883721
# Name: UAL, dtype: float64
# UDR Symbol
# EQR    1.000000
# AVB    0.943925
# AIV    0.887850
# Name: UDR, dtype: float64
# UHS Symbol
# DVA    1.0000
# HCA    1.0000
# CAH    0.9375
# Name: UHS, dtype: float64
# ULTA Symbol
# ADP     1.000000
# ROST    0.900000
# FLT     0.833333
# Name: ULTA, dtype: float64
# UNH Symbol
# ANTM    1.000000
# CNC     0.977273
# HUM     0.977273
# Name: UNH, dtype: float64
# UNM Symbol
# LNC    1.00
# DFS    0.84
# PFG    0.84
# Name: UNM, dtype: float64
# UNP Symbol
# NSC    1.000000
# CSX    0.885057
# RTX    0.862069
# Name: UNP, dtype: float64
# UPS Symbol
# FDX     1.000000
# BLK     0.909091
# PCAR    0.909091
# Name: UPS, dtype: float64
# URI Symbol
# PH     1.000000
# BLK    0.899160
# CAT    0.865546
# Name: URI, dtype: float64
# USB Symbol
# PNC    1.00
# COF    0.98
# BAC    0.92
# Name: USB, dtype: float64
# V Symbol
# MA      1.000000
# MSFT    0.663366
# ACN     0.524752
# Name: V, dtype: float64
# VAR Symbol
# A      1.000000
# TMO    0.947368
# DHR    0.921053
# Name: VAR, dtype: float64
# VFC Symbol
# ITW    1.000000
# GWW    0.930233
# GPC    0.883721
# Name: VFC, dtype: float64
# VLO Symbol
# HFC    1.000000
# PSX    0.935484
# MPC    0.913978
# Name: VLO, dtype: float64
# VMC Symbol
# MLM     1.000000
# LDOS    0.431579
# LMT     0.368421
# Name: VMC, dtype: float64
# VNO Symbol
# BXP    1.000000
# SLG    0.857143
# FRT    0.738095
# Name: VNO, dtype: float64
# VRSK Symbol
# INFO    1.000000
# PAYX    1.000000
# CTAS    0.945946
# Name: VRSK, dtype: float64
# VRSN Symbol
# MSFT    1.000000
# SPGI    0.972973
# MCO     0.945946
# Name: VRSN, dtype: float64
# VRTX Symbol
# ALXN    1.000000
# INCY    0.859155
# PKI     0.859155
# Name: VRTX, dtype: float64
# VTR Symbol
# PEAK    1.000000
# WELL    0.883495
# AIV     0.611650
# Name: VTR, dtype: float64
# VZ Symbol
# TMUS    1.000000
# WLTW    0.966667
# CB      0.933333
# Name: VZ, dtype: float64
# WAB Symbol
# MMM    1.000000
# ITW    0.906977
# XRX    0.883721
# Name: WAB, dtype: float64
# WAT Symbol
# A      1.000000
# TMO    0.827160
# MTD    0.753086
# Name: WAT, dtype: float64
# WBA Symbol
# CAH    1.000000
# CVS    0.945205
# ABC    0.890411
# Name: WBA, dtype: float64
# WDC Symbol
# MU      1.0
# GM      0.7
# MXIM    0.7
# Name: WDC, dtype: float64
# WEC Symbol
# AEP    1.0
# CMS    1.0
# XEL    1.0
# Name: WEC, dtype: float64
# WELL Symbol
# PEAK    1.000000
# VTR     1.000000
# AIV     0.979167
# Name: WELL, dtype: float64
# WFC Symbol
# BAC    1.000000
# USB    1.000000
# COF    0.979798
# Name: WFC, dtype: float64
# WHR Symbol
# SWK     1.000000
# MHK     0.815789
# FBHS    0.710526
# Name: WHR, dtype: float64
# WLTW Symbol
# MMC    1.000000
# AJG    0.880597
# AON    0.761194
# Name: WLTW, dtype: float64
# WM Symbol
# RSG    1.000000
# CL     0.922078
# CB     0.844156
# Name: WM, dtype: float64
# WMB Symbol
# OKE    1.000000
# EOG    0.590909
# XOM    0.568182
# Name: WMB, dtype: float64
# WMT Symbol
# ORLY    1.000000
# DG      0.924528
# GOOG    0.924528
# Name: WMT, dtype: float64
# WRB Symbol
# CINF    1.000000
# TRV     0.790698
# CB      0.767442
# Name: WRB, dtype: float64
# WRK Symbol
# IP     1.000000
# PKG    0.956522
# DOV    0.673913
# Name: WRK, dtype: float64
# WU Symbol
# RTX      1.000000
# GOOGL    0.967213
# DIS      0.901639
# Name: WU, dtype: float64
# WY Symbol
# URI    1.000000
# BLK    0.944444
# SWK    0.944444
# Name: WY, dtype: float64
# WYNN Symbol
# URI    1.000000
# LVS    0.979592
# EMN    0.959184
# Name: WYNN, dtype: float64
# XEL Symbol
# CMS    1.000000
# AEP    0.932773
# WEC    0.915966
# Name: XEL, dtype: float64
# XLNX Symbol
# INTC    1.000000
# MCHP    1.000000
# MXIM    0.931034
# Name: XLNX, dtype: float64
# XOM Symbol
# DVN    1.000000
# PXD    0.939394
# CVX    0.898990
# Name: XOM, dtype: float64
# XRAY Symbol
# HSIC    1.000000
# COO     0.833333
# HOLX    0.833333
# Name: XRAY, dtype: float64
# XRX Symbol
# GM      1.000000
# HPE     1.000000
# NTAP    0.925926
# Name: XRX, dtype: float64
# XYL Symbol
# ROK    1.000000
# RHI    0.932584
# FTV    0.842697
# Name: XYL, dtype: float64
# YUM Symbol
# VRSK    1.000000
# AJG     0.968254
# CTAS    0.904762
# Name: YUM, dtype: float64
# ZBH Symbol
# SYK    1.000000
# ABT    0.887324
# EW     0.774648
# Name: ZBH, dtype: float64
# ZBRA Symbol
# AME    1.000000
# CDW    0.861111
# ETN    0.861111
# Name: ZBRA, dtype: float64
# ZION Symbol
# CFG     1.000000
# FITB    1.000000
# CMA     0.957447
# Name: ZION, dtype: float64
# ZTS Symbol
# CTAS    1.00000
# IDXX    0.97561
# MRK     0.95122
# Name: ZTS, dtype: float64
