# %%
import pandas as pd 
import numpy as np

import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('stocks/total_data_price_Change_Symbol.csv', index_col = 'Symbol')
df.head()
# Out:
#         2019-01-31  2019-02-01  2019-02-04  2019-02-05  2019-02-06  \
# Symbol
# A             0.92        0.82        0.19        0.09        0.09
# AAL          -0.26       -0.06        0.14        0.41        0.25
# AAP           1.44        1.21        0.77        0.75       -0.60
# AAPL          3.31        3.87        1.96        2.53        2.52
# ABBV          0.96        0.93       -0.16       -0.18       -0.43
#
#         2019-02-07  2019-02-08  2019-02-11  2019-02-12  2019-02-13  ...  \
# Symbol                                                              ...
# A            -0.23       -0.17       -0.07        0.57        0.48  ...
# AAL          -0.17       -0.31       -0.06       -0.14        0.07  ...
# AAP           0.59        0.32        2.63        1.58        1.34  ...
# AAPL         -0.10       -0.99       -1.33        0.22       -0.08  ...
# ABBV          0.20       -0.01        0.21        0.23        0.34  ...
#
#         2019-12-17  2019-12-18  2019-12-19  2019-12-20  2019-12-23  \
# Symbol
# A            -0.29       -0.09        0.02        0.41        0.61
# AAL           0.19        0.17        0.21        0.25        0.43
# AAP           0.62        0.94        1.01        0.07        0.66
# AAPL          2.97        1.52        0.05       -0.32        1.41
# ABBV          0.44        0.48       -0.21       -0.26        0.30
#
#         2019-12-24  2019-12-26  2019-12-27  2019-12-30  2019-12-31
# Symbol
# A             0.26        0.09        0.05       -0.07        0.01
# AAL           0.21        0.21       -0.29       -0.29       -0.33
# AAP           1.36        0.38       -0.54       -0.48        0.30
# AAPL          1.41        3.47        1.92        2.40        1.24
# ABBV          0.35        0.17       -0.34       -0.43       -0.42
#
# [5 rows x 232 columns]

# %%
def calculate_timeseries_correlation(data):
    result = []
    days = data.shape[1]
    
    for i in range(len(data)):
        symbol_corr = []
        for j in range(len(data)):
            if i == j :
                symbol_corr.append(0)
                continue

            change = [1 if np.sign(data[i , day]) == np.sign(data[j , day])
                      else 0 if data[i , day] == 0 and data[j , day] == 0
                      else -1 
                      for day in range(days)]

            symbol_corr.append(sum(change))

        result.append(symbol_corr)
    return result

# %%
symbols = df.index
data = df.to_numpy()
correlation = calculate_timeseries_correlation(data)

# %%
df_corr = pd.DataFrame(correlation, columns = symbols , index = symbols) 
df_corr.head()
# Out:
# Symbol   A  AAL  AAP  AAPL  ABBV  ABC  ABMD  ABT  ACN  ADBE  ...  XLNX  XOM  \
# Symbol                                                       ...
# A        0   50   24    88    72   48    52   88  100    76  ...    62   74
# AAL     50    0   42    60    56   26    18   36   40    48  ...    56   76
# AAP     24   42    0    46    62   12    16   20   36    22  ...    36   48
# AAPL    88   60   46     0    48    8    40   68   82    54  ...    74   80
# ABBV    72   56   62    48     0   50    84   78   94    54  ...    26   58
#
# Symbol  XRAY  XRX  XYL  YUM  ZBH  ZBRA  ZION  ZTS
# Symbol
# A         46   68   70   24   70    76    60   78
# AAL        2   76   60   -6   38    32    74   38
# AAP       28   70   60    8   24    22    48   22
# AAPL      14   78   68   34   60    72    50   58
# ABBV      48   62   56   16   58    44    68   56
#
# [5 rows x 493 columns]

# %%
for col in df_corr.columns:
    print(col , df_corr[col].nlargest(3))
# Out:
# A Symbol
# TMO    136
# PKI    132
# WAT    132
# Name: A, dtype: int64
# AAL Symbol
# FDX    124
# UAL    124
# DAL    122
# Name: AAL, dtype: int64
# AAP Symbol
# GPC     108
# CSCO     86
# AZO      82
# Name: AAP, dtype: int64
# AAPL Symbol
# KLAC    130
# NVDA    120
# APH     118
# Name: AAPL, dtype: int64
# ABBV Symbol
# CTXS    96
# DGX     96
# FBHS    96
# Name: ABBV, dtype: int64
# ABC Symbol
# MCK    136
# CAH    114
# CVS     98
# Name: ABC, dtype: int64
# ABMD Symbol
# MYL     90
# MDT     88
# ABBV    84
# Name: ABMD, dtype: int64
# ABT Symbol
# SYK    144
# TMO    114
# MDT    112
# Name: ABT, dtype: int64
# ACN Symbol
# MA      140
# V       138
# MSFT    134
# Name: ACN, dtype: int64
# ADBE Symbol
# ANSS    138
# NOW     138
# ADSK    134
# Name: ADBE, dtype: int64
# ADI Symbol
# MCHP    148
# TXN     140
# MXIM    136
# Name: ADI, dtype: int64
# ADM Symbol
# FDX    102
# C       98
# LYB     98
# Name: ADM, dtype: int64
# ADP Symbol
# PAYX    124
# ANSS    120
# INTU    120
# Name: ADP, dtype: int64
# ADS Symbol
# ALB    120
# PFG    114
# UNM    114
# Name: ADS, dtype: int64
# ADSK Symbol
# ADBE    134
# NOW     116
# ANSS    112
# Name: ADSK, dtype: int64
# AEE Symbol
# LNT    154
# CMS    150
# XEL    150
# Name: AEE, dtype: int64
# AEP Symbol
# CMS    166
# XEL    166
# WEC    164
# Name: AEP, dtype: int64
# AES Symbol
# GPC    88
# D      84
# LNT    78
# Name: AES, dtype: int64
# AFL Symbol
# HIG    108
# AON    100
# TRV    100
# Name: AFL, dtype: int64
# AIG Symbol
# MET    94
# AIZ    92
# RE     92
# Name: AIG, dtype: int64
# AIV Symbol
# UDR    154
# MAA    148
# AVB    146
# Name: AIV, dtype: int64
# AIZ Symbol
# AIG    92
# HIG    82
# MMC    82
# Name: AIZ, dtype: int64
# AJG Symbol
# AON     144
# MMC     142
# WLTW    126
# Name: AJG, dtype: int64
# AKAM Symbol
# INFO    100
# TWTR     90
# CDW      86
# Name: AKAM, dtype: int64
# ALB Symbol
# IBM    122
# ADS    120
# C      116
# Name: ALB, dtype: int64
# ALGN Symbol
# IDXX    80
# AMGN    76
# AMD     74
# Name: ALGN, dtype: int64
# ALK Symbol
# AAL     120
# SIVB    118
# FDX     116
# Name: ALK, dtype: int64
# ALL Symbol
# HIG    98
# PFG    94
# NKE    92
# Name: ALL, dtype: int64
# ALLE Symbol
# AME     110
# BLK     104
# FBHS    104
# Name: ALLE, dtype: int64
# ALXN Symbol
# VAR     100
# VRTX    100
# REGN     94
# Name: ALXN, dtype: int64
# AMAT Symbol
# LRCX    148
# NVDA    132
# KLAC    130
# Name: AMAT, dtype: int64
# AMCR Symbol
# MTD     32
# ADBE    16
# HLT     16
# Name: AMCR, dtype: int64
# AMD Symbol
# KLAC    110
# MU      106
# CDW     100
# Name: AMD, dtype: int64
# AME Symbol
# ITW    142
# FLS    138
# EMR    136
# Name: AME, dtype: int64
# AMGN Symbol
# MRK     104
# ZTS     102
# GILD     96
# Name: AMGN, dtype: int64
# AMP Symbol
# DFS    144
# LNC    134
# URI    134
# Name: AMP, dtype: int64
# AMT Symbol
# CCI     128
# SBAC    106
# PSA     102
# Name: AMT, dtype: int64
# AMZN Symbol
# GOOGL    118
# FB       116
# GOOG     114
# Name: AMZN, dtype: int64
# ANET Symbol
# CSCO    98
# NSC     96
# GLW     94
# Name: ANET, dtype: int64
# ANSS Symbol
# ADBE    138
# CDNS    130
# NOW     128
# Name: ANSS, dtype: int64
# ANTM Symbol
# UNH    130
# CNC    114
# HUM    102
# Name: ANTM, dtype: int64
# AON Symbol
# AJG    144
# MMC    126
# HIG    118
# Name: AON, dtype: int64
# AOS Symbol
# ETN     126
# IPGP    126
# EMN     120
# Name: AOS, dtype: int64
# APA Symbol
# DVN    138
# EOG    126
# HP     118
# Name: APA, dtype: int64
# APD Symbol
# LIN    118
# IEX    108
# ECL    106
# Name: APD, dtype: int64
# APH Symbol
# FTV    142
# DOV    138
# TEL    138
# Name: APH, dtype: int64
# APTV Symbol
# GM     154
# BWA    150
# PH     140
# Name: APTV, dtype: int64
# ARE Symbol
# DRE    124
# BXP    116
# UDR    116
# Name: ARE, dtype: int64
# ATO Symbol
# AEE    148
# LNT    148
# CMS    140
# Name: ATO, dtype: int64
# ATVI Symbol
# EA    92
# MA    92
# V     86
# Name: ATVI, dtype: int64
# AVB Symbol
# EQR    164
# UDR    160
# PLD    148
# Name: AVB, dtype: int64
# AVGO Symbol
# GM     120
# FDX    112
# SWK    112
# Name: AVGO, dtype: int64
# AVY Symbol
# ETN    120
# DOV    112
# ITW    110
# Name: AVY, dtype: int64
# AWK Symbol
# CMS    150
# LNT    148
# NEE    134
# Name: AWK, dtype: int64
# AXP Symbol
# DFS     122
# ADI     114
# GOOG    108
# Name: AXP, dtype: int64
# AZO Symbol
# ORLY    120
# CMI     102
# ADI      98
# Name: AZO, dtype: int64
# BA Symbol
# LUV     94
# PH      82
# AMAT    80
# Name: BA, dtype: int64
# BAC Symbol
# C       166
# PNC     158
# FITB    156
# Name: BAC, dtype: int64
# BAX Symbol
# HOLX    116
# ABT     110
# EBAY    100
# Name: BAX, dtype: int64
# BBY Symbol
# BLK    114
# ITW    106
# GS     104
# Name: BBY, dtype: int64
# BDX Symbol
# ISRG    98
# HOLX    96
# BSX     94
# Name: BDX, dtype: int64
# BEN Symbol
# LNC     130
# PFG     120
# TROW    118
# Name: BEN, dtype: int64
# BIIB Symbol
# SIVB    94
# COF     92
# PH      92
# Name: BIIB, dtype: int64
# BK Symbol
# NTRS    130
# FITB    122
# BLK     118
# Name: BK, dtype: int64
# BKNG Symbol
# IPGP    108
# APH     106
# FLS     106
# Name: BKNG, dtype: int64
# BKR Symbol
# FTI    110
# SLB    100
# XOM     98
# Name: BKR, dtype: int64
# BLK Symbol
# URI    150
# COF    148
# C      142
# Name: BLK, dtype: int64
# BLL Symbol
# SYK     98
# LDOS    88
# TFX     86
# Name: BLL, dtype: int64
# BMY Symbol
# PKI     74
# MAS     72
# FBHS    68
# Name: BMY, dtype: int64
# BR Symbol
# V       116
# JKHY    114
# CTAS    112
# Name: BR, dtype: int64
# BSX Symbol
# SYK    122
# ABT    108
# MDT    108
# Name: BSX, dtype: int64
# BWA Symbol
# EMN     154
# APTV    150
# PH      150
# Name: BWA, dtype: int64
# BXP Symbol
# VNO    148
# SLG    120
# REG    118
# Name: BXP, dtype: int64
# C Symbol
# BAC    166
# MS     158
# JPM    154
# Name: C, dtype: int64
# CAG Symbol
# K      108
# GIS     86
# CPB     76
# Name: CAG, dtype: int64
# CAH Symbol
# CVS    126
# MCK    124
# ABC    114
# Name: CAH, dtype: int64
# CAT Symbol
# EMR    158
# ETN    150
# PH     148
# Name: CAT, dtype: int64
# CB Symbol
# CL      134
# TRV     134
# CINF    126
# Name: CB, dtype: int64
# CBOE Symbol
# CME     104
# ICE      92
# MKTX     82
# Name: CBOE, dtype: int64
# CBRE Symbol
# ETN    114
# IEX    108
# URI    106
# Name: CBRE, dtype: int64
# CCI Symbol
# SBAC    138
# AMT     128
# EXR     120
# Name: CCI, dtype: int64
# CCL Symbol
# NCLH    136
# RCL     136
# C       126
# Name: CCL, dtype: int64
# CDNS Symbol
# SNPS    144
# MA      132
# ADBE    130
# Name: CDNS, dtype: int64
# CDW Symbol
# ACN     112
# KLAC    112
# MCO     112
# Name: CDW, dtype: int64
# CE Symbol
# URI    136
# SNA    128
# ETN    124
# Name: CE, dtype: int64
# CERN Symbol
# LH      98
# GILD    96
# ACN     92
# Name: CERN, dtype: int64
# CF Symbol
# MOS    112
# CMA     86
# CAT     84
# Name: CF, dtype: int64
# CFG Symbol
# FITB    156
# BAC     152
# KEY     152
# Name: CFG, dtype: int64
# CHD Symbol
# CL     108
# KMB    104
# MKC    104
# Name: CHD, dtype: int64
# CHRW Symbol
# EXPD    118
# ODFL    108
# AOS     104
# Name: CHRW, dtype: int64
# CHTR Symbol
# CMCSA    90
# GPN      90
# AMZN     88
# Name: CHTR, dtype: int64
# CI Symbol
# HUM    122
# CVS    112
# CNC    110
# Name: CI, dtype: int64
# CINF Symbol
# CB     126
# WRB    124
# TRV    122
# Name: CINF, dtype: int64
# CL Symbol
# PG    138
# CB    134
# WM    114
# Name: CL, dtype: int64
# CLX Symbol
# KMB    104
# KO      96
# CB      94
# Name: CLX, dtype: int64
# CMA Symbol
# CFG     136
# ZION    136
# MTB     134
# Name: CMA, dtype: int64
# CMCSA Symbol
# OMC    110
# NKE    102
# ACN    100
# Name: CMCSA, dtype: int64
# CME Symbol
# ICE     140
# CBOE    104
# NDAQ     96
# Name: CME, dtype: int64
# CMG Symbol
# AMT     72
# SBAC    72
# TWTR    64
# Name: CMG, dtype: int64
# CMI Symbol
# ITW     150
# ETN     140
# PCAR    138
# Name: CMI, dtype: int64
# CMS Symbol
# LNT    184
# XEL    174
# AEP    166
# Name: CMS, dtype: int64
# CNC Symbol
# UNH     128
# HUM     116
# ANTM    114
# Name: CNC, dtype: int64
# CNP Symbol
# ATO    94
# DTE    82
# NI     82
# Name: CNP, dtype: int64
# COF Symbol
# FITB    156
# PNC     154
# DFS     152
# Name: COF, dtype: int64
# COG Symbol
# APA    66
# EOG    66
# HP     66
# Name: COG, dtype: int64
# COO Symbol
# SYK     110
# TFX     102
# ADBE    100
# Name: COO, dtype: int64
# COP Symbol
# MRO    130
# PXD    126
# HES    124
# Name: COP, dtype: int64
# COST Symbol
# TJX     106
# ROST     98
# LOW      86
# Name: COST, dtype: int64
# COTY Symbol
# HBI     64
# EXPD    56
# PFG     54
# Name: COTY, dtype: int64
# CPB Symbol
# K      80
# CAG    76
# SJM    70
# Name: CPB, dtype: int64
# CPRT Symbol
# EBAY    108
# MCO     104
# VRSN    102
# Name: CPRT, dtype: int64
# CRM Symbol
# NOW     122
# INTU    118
# ADBE    112
# Name: CRM, dtype: int64
# CSCO Symbol
# FTV    118
# ITW    112
# PH     106
# Name: CSCO, dtype: int64
# CSX Symbol
# PCAR    134
# RTX     128
# UNP     128
# Name: CSX, dtype: int64
# CTAS Symbol
# ECL    118
# ZTS    118
# BR     112
# Name: CTAS, dtype: int64
# CTL Symbol
# BWA    62
# IRM    58
# WBA    58
# Name: CTL, dtype: int64
# CTSH Symbol
# TROW    98
# IBM     94
# PCAR    94
# Name: CTSH, dtype: int64
# CTXS Symbol
# TMO     102
# MCO     100
# ABBV     96
# Name: CTXS, dtype: int64
# CVS Symbol
# CAH    126
# CI     112
# MCK    108
# Name: CVS, dtype: int64
# CVX Symbol
# XOM    136
# HP     116
# MRO    114
# Name: CVX, dtype: int64
# CXO Symbol
# EOG     152
# DVN     138
# FANG    138
# Name: CXO, dtype: int64
# D Symbol
# DTE    122
# AEP    120
# CMS    118
# Name: D, dtype: int64
# DAL Symbol
# UAL    132
# AAL    122
# GS     116
# Name: DAL, dtype: int64
# DD Symbol
# BWA    114
# LYB    114
# CMI    108
# Name: DD, dtype: int64
# DE Symbol
# CAT    130
# ETN    120
# AOS    114
# Name: DE, dtype: int64
# DFS Symbol
# COF    152
# MET    150
# AMP    144
# Name: DFS, dtype: int64
# DG Symbol
# ROST    94
# DLTR    90
# EFX     88
# Name: DG, dtype: int64
# DGX Symbol
# LH      132
# ABBV     96
# DVA      94
# Name: DGX, dtype: int64
# DHI Symbol
# LEN    126
# PHM    100
# NVR     92
# Name: DHI, dtype: int64
# DHR Symbol
# TMO    128
# MRK    114
# PKI    110
# Name: DHR, dtype: int64
# DIS Symbol
# ACN     102
# LKQ      94
# TROW     90
# Name: DIS, dtype: int64
# DISCA Symbol
# DISCK    202
# OMC       90
# VFC       86
# Name: DISCA, dtype: int64
# DISCK Symbol
# DISCA    202
# APTV      90
# C         90
# Name: DISCK, dtype: int64
# DISH Symbol
# HON      92
# CMCSA    88
# VFC      88
# Name: DISH, dtype: int64
# DLR Symbol
# PEAK    114
# FRT     100
# EQIX     98
# Name: DLR, dtype: int64
# DLTR Symbol
# DG     90
# TJX    90
# VFC    86
# Name: DLTR, dtype: int64
# DOV Symbol
# ETN    142
# CAT    140
# APH    138
# Name: DOV, dtype: int64
# DPZ Symbol
# RTX    76
# ALK    68
# HBI    66
# Name: DPZ, dtype: int64
# DRE Symbol
# PLD    134
# AVB    130
# UDR    130
# Name: DRE, dtype: int64
# DRI Symbol
# CLX     68
# TROW    64
# UHS     64
# Name: DRI, dtype: int64
# DTE Symbol
# AEE    148
# CMS    146
# AEP    142
# Name: DTE, dtype: int64
# DUK Symbol
# AEP    144
# LNT    140
# PNW    134
# Name: DUK, dtype: int64
# DVA Symbol
# HCA    118
# CI     110
# DOV    104
# Name: DVA, dtype: int64
# DVN Symbol
# EOG    178
# XOM    146
# PXD    142
# Name: DVN, dtype: int64
# DXC Symbol
# TXT    108
# IBM    104
# BLK    102
# Name: DXC, dtype: int64
# DXCM Symbol
# COO     70
# JKHY    68
# SYK     64
# Name: DXCM, dtype: int64
# EA Symbol
# ATVI    92
# ADSK    78
# OKE     74
# Name: EA, dtype: int64
# EBAY Symbol
# MCO     118
# CPRT    108
# BLK     106
# Name: EBAY, dtype: int64
# ECL Symbol
# CTAS    118
# IEX     116
# APD     106
# Name: ECL, dtype: int64
# ED Symbol
# NEE    146
# AEP    144
# ETR    144
# Name: ED, dtype: int64
# EFX Symbol
# ACN    116
# HD     108
# MCO    106
# Name: EFX, dtype: int64
# EIX Symbol
# SO     80
# ATO    76
# D      76
# Name: EIX, dtype: int64
# EL Symbol
# CL      110
# MDLZ     96
# NKE      96
# Name: EL, dtype: int64
# EMN Symbol
# BWA    154
# GM     150
# LYB    148
# Name: EMN, dtype: int64
# EMR Symbol
# PH     162
# CAT    158
# ETN    158
# Name: EMR, dtype: int64
# EOG Symbol
# DVN    178
# CXO    152
# PXD    144
# Name: EOG, dtype: int64
# EQIX Symbol
# CCI     104
# DLR      98
# SBAC     94
# Name: EQIX, dtype: int64
# EQR Symbol
# UDR    166
# AVB    164
# ESS    158
# Name: EQR, dtype: int64
# ES Symbol
# CMS    136
# ED     130
# LNT    130
# Name: ES, dtype: int64
# ESS Symbol
# EQR    158
# UDR    152
# AVB    146
# Name: ESS, dtype: int64
# ETFC Symbol
# MS      134
# SCHW    134
# BLK     126
# Name: ETFC, dtype: int64
# ETN Symbol
# EMR    158
# PH     154
# CAT    150
# Name: ETN, dtype: int64
# ETR Symbol
# CMS    150
# AEP    146
# LNT    146
# Name: ETR, dtype: int64
# EVRG Symbol
# LNT    134
# AEE    130
# DTE    128
# Name: EVRG, dtype: int64
# EW Symbol
# SYK    110
# ZBH    104
# MDT    102
# Name: EW, dtype: int64
# EXC Symbol
# AEP     112
# EVRG    112
# DTE     110
# Name: EXC, dtype: int64
# EXPD Symbol
# ODFL    140
# TEL     136
# LEG     130
# Name: EXPD, dtype: int64
# EXPE Symbol
# BKNG    104
# BK       80
# AVGO     78
# Name: EXPE, dtype: int64
# EXR Symbol
# PSA    124
# CCI    120
# ESS    112
# Name: EXR, dtype: int64
# F Symbol
# BWA    100
# SNA    100
# URI     98
# Name: F, dtype: int64
# FANG Symbol
# CXO    138
# EOG    124
# MRO    124
# Name: FANG, dtype: int64
# FAST Symbol
# ITW    128
# ETN    126
# TEL    126
# Name: FAST, dtype: int64
# FB Symbol
# AMZN    116
# GOOG     94
# ADSK     92
# Name: FB, dtype: int64
# FBHS Symbol
# SNA    126
# URI    126
# BLK    118
# Name: FBHS, dtype: int64
# FCX Symbol
# EMN    142
# BWA    136
# CAT    134
# Name: FCX, dtype: int64
# FDX Symbol
# UPS     138
# SIVB    134
# C       132
# Name: FDX, dtype: int64
# FE Symbol
# CMS    126
# NI     126
# XEL    124
# Name: FE, dtype: int64
# FFIV Symbol
# EMN    134
# ITW    126
# GLW    124
# Name: FFIV, dtype: int64
# FIS Symbol
# FISV    128
# MA      110
# GPN     106
# Name: FIS, dtype: int64
# FISV Symbol
# FIS    128
# MDT     92
# MA      90
# Name: FISV, dtype: int64
# FITB Symbol
# PNC    160
# BAC    156
# CFG    156
# Name: FITB, dtype: int64
# FLIR Symbol
# ROK    116
# URI    112
# BLK    110
# Name: FLIR, dtype: int64
# FLS Symbol
# EMR    148
# ETN    148
# MMM    146
# Name: FLS, dtype: int64
# FLT Symbol
# PYPL    128
# ANSS    114
# V       114
# Name: FLT, dtype: int64
# FMC Symbol
# APTV    108
# CE      106
# PH      104
# Name: FMC, dtype: int64
# FRC Symbol
# MTB    124
# RF     124
# BLK    122
# Name: FRC, dtype: int64
# FRT Symbol
# REG    158
# KIM    132
# VNO    126
# Name: FRT, dtype: int64
# FTI Symbol
# MRO    116
# EOG    114
# SLB    114
# Name: FTI, dtype: int64
# FTNT Symbol
# ADSK    112
# ADBE     98
# ANSS     98
# Name: FTNT, dtype: int64
# FTV Symbol
# ITW    146
# APH    142
# MMM    136
# Name: FTV, dtype: int64
# GD Symbol
# HII     124
# TROW    108
# RTX     100
# Name: GD, dtype: int64
# GE Symbol
# HON    112
# EMR    106
# PPG    106
# Name: GE, dtype: int64
# GILD Symbol
# OMC    100
# PFG    100
# MET     98
# Name: GILD, dtype: int64
# GIS Symbol
# K       92
# MDLZ    88
# TRV     88
# Name: GIS, dtype: int64
# GL Symbol
# MET    138
# AMP    130
# PRU    124
# Name: GL, dtype: int64
# GLW Symbol
# APH    136
# CAT    136
# SWK    134
# Name: GLW, dtype: int64
# GM Symbol
# APTV    154
# EMN     150
# BWA     134
# Name: GM, dtype: int64
# GOOG Symbol
# GOOGL    224
# MSFT     118
# AMZN     114
# Name: GOOG, dtype: int64
# GOOGL Symbol
# GOOG    224
# AMZN    118
# MSFT    114
# Name: GOOGL, dtype: int64
# GPC Symbol
# GWW    128
# APH    126
# VFC    122
# Name: GPC, dtype: int64
# GPN Symbol
# MA      140
# V       134
# PAYX    118
# Name: GPN, dtype: int64
# GPS Symbol
# KSS    110
# JWN     92
# LB      88
# Name: GPS, dtype: int64
# GRMN Symbol
# ANSS    104
# AMGN     92
# PH       92
# Name: GRMN, dtype: int64
# GS Symbol
# MS     152
# JPM    150
# BAC    148
# Name: GS, dtype: int64
# GWW Symbol
# GPC    128
# VFC    126
# ITW    120
# Name: GWW, dtype: int64
# HAL Symbol
# SLB    168
# HP     134
# DVN    132
# Name: HAL, dtype: int64
# HAS Symbol
# FDX    98
# IFF    98
# BLK    92
# Name: HAS, dtype: int64
# HBAN Symbol
# RF      140
# FITB    138
# KEY     138
# Name: HBAN, dtype: int64
# HBI Symbol
# LEG     108
# EXPD    104
# URI     100
# Name: HBI, dtype: int64
# HCA Symbol
# DVA     118
# NTRS    104
# MS      102
# Name: HCA, dtype: int64
# HD Symbol
# LOW    138
# MMM    120
# BLK    108
# Name: HD, dtype: int64
# HES Symbol
# PXD    134
# EOG    132
# COP    124
# Name: HES, dtype: int64
# HFC Symbol
# MPC    124
# VLO    122
# PSX    116
# Name: HFC, dtype: int64
# HIG Symbol
# CB      124
# AON     118
# WLTW    118
# Name: HIG, dtype: int64
# HII Symbol
# GD      124
# RTX     116
# TROW    102
# Name: HII, dtype: int64
# HLT Symbol
# MAR    132
# BLK    120
# CCL    120
# Name: HLT, dtype: int64
# HOG Symbol
# URI    130
# CAT    126
# PH     126
# Name: HOG, dtype: int64
# HOLX Symbol
# BAX    116
# TFX    106
# BSX    100
# Name: HOLX, dtype: int64
# HON Symbol
# PPG    146
# BLK    138
# ETN    130
# Name: HON, dtype: int64
# HP Symbol
# EOG    136
# HAL    134
# SLB    124
# Name: HP, dtype: int64
# HPE Symbol
# HPQ     132
# CMI     130
# NTAP    124
# Name: HPE, dtype: int64
# HPQ Symbol
# HPE    132
# CMI    114
# EMR    112
# Name: HPQ, dtype: int64
# HRB Symbol
# ALK    64
# LEG    58
# FDX    56
# Name: HRB, dtype: int64
# HRL Symbol
# PEP    64
# PG     58
# HSY    56
# Name: HRL, dtype: int64
# HSIC Symbol
# PPG    96
# DVA    90
# LH     90
# Name: HSIC, dtype: int64
# HST Symbol
# MAR    108
# IR     106
# SWK    106
# Name: HST, dtype: int64
# HSY Symbol
# MKC    104
# WRB     92
# CHD     86
# Name: HSY, dtype: int64
# HUM Symbol
# UNH    128
# CI     122
# CNC    116
# Name: HUM, dtype: int64
# IBM Symbol
# ITW    132
# CMI    126
# ALB    122
# Name: IBM, dtype: int64
# ICE Symbol
# CME     140
# NDAQ    132
# AON      98
# Name: ICE, dtype: int64
# IDXX Symbol
# ZTS    116
# SYK    112
# TFX    108
# Name: IDXX, dtype: int64
# IEX Symbol
# AME    128
# ITW    122
# ECL    116
# Name: IEX, dtype: int64
# IFF Symbol
# HAS    98
# URI    94
# BLK    92
# Name: IFF, dtype: int64
# ILMN Symbol
# DHR    104
# PKI    102
# IQV    100
# Name: ILMN, dtype: int64
# INCY Symbol
# VRTX    90
# AMGN    88
# MRK     80
# Name: INCY, dtype: int64
# INFO Symbol
# VRSK    114
# MA      110
# AON     108
# Name: INFO, dtype: int64
# INTC Symbol
# ITW    138
# APH    136
# EMR    136
# Name: INTC, dtype: int64
# INTU Symbol
# NOW     128
# SNPS    126
# PAYC    124
# Name: INTU, dtype: int64
# IP Symbol
# WRK    142
# PKG    134
# RTX    114
# Name: IP, dtype: int64
# IPG Symbol
# OMC    144
# AMP    108
# RTX    104
# Name: IPG, dtype: int64
# IPGP Symbol
# TEL    142
# EMN    132
# AOS    126
# Name: IPGP, dtype: int64
# IQV Symbol
# SYK     112
# ANSS    106
# BSX     104
# Name: IQV, dtype: int64
# IR Symbol
# CMI    114
# BAC    112
# HLT    110
# Name: IR, dtype: int64
# IRM Symbol
# REG    88
# TAP    76
# KHC    74
# Name: IRM, dtype: int64
# ISRG Symbol
# VRSN    110
# PYPL    104
# BDX      98
# Name: ISRG, dtype: int64
# IT Symbol
# MSFT    114
# ACN     112
# TROW    110
# Name: IT, dtype: int64
# ITW Symbol
# PH     160
# CMI    150
# EMR    150
# Name: ITW, dtype: int64
# IVZ Symbol
# PRU    126
# PFG    114
# LNC    110
# Name: IVZ, dtype: int64
# J Symbol
# CAT    124
# FLS    122
# ETN    118
# Name: J, dtype: int64
# JBHT Symbol
# EXPD    114
# MHK     108
# LEG     106
# Name: JBHT, dtype: int64
# JCI Symbol
# DOV    100
# PPG     90
# ETN     88
# Name: JCI, dtype: int64
# JKHY Symbol
# BR      114
# ACN     108
# MSCI    108
# Name: JKHY, dtype: int64
# JNJ Symbol
# MRK    100
# HAS     86
# LLY     86
# Name: JNJ, dtype: int64
# JNPR Symbol
# XRX     102
# NVDA    100
# PCAR    100
# Name: JNPR, dtype: int64
# JPM Symbol
# C      154
# BAC    152
# GS     150
# Name: JPM, dtype: int64
# JWN Symbol
# KSS    100
# GPS     92
# RL      92
# Name: JWN, dtype: int64
# K Symbol
# CAG    108
# GIS     92
# CPB     80
# Name: K, dtype: int64
# KEY Symbol
# CFG     152
# FITB    150
# PNC     146
# Name: KEY, dtype: int64
# KEYS Symbol
# HON    116
# IEX    116
# APH    112
# Name: KEYS, dtype: int64
# KHC Symbol
# BWA    86
# DVN    74
# IRM    74
# Name: KHC, dtype: int64
# KIM Symbol
# REG    136
# FRT    132
# SPG    106
# Name: KIM, dtype: int64
# KLAC Symbol
# LRCX    136
# AAPL    130
# AMAT    130
# Name: KLAC, dtype: int64
# KMB Symbol
# PG     120
# CL     112
# CHD    104
# Name: KMB, dtype: int64
# KMI Symbol
# OKE    108
# WMB     96
# CVX     94
# Name: KMI, dtype: int64
# KMX Symbol
# PRU     90
# FITB    88
# PBCT    86
# Name: KMX, dtype: int64
# KO Symbol
# PEP    108
# CLX     96
# WM      96
# Name: KO, dtype: int64
# KR Symbol
# URI    62
# ADM    60
# MET    60
# Name: KR, dtype: int64
# KSS Symbol
# GPS    110
# JWN    100
# CCL     94
# Name: KSS, dtype: int64
# KSU Symbol
# APH    106
# DOV    106
# NSC    106
# Name: KSU, dtype: int64
# L Symbol
# BLK    122
# PFG    120
# TAP    116
# Name: L, dtype: int64
# LB Symbol
# GPS    88
# BEN    76
# TXT    76
# Name: LB, dtype: int64
# LDOS Symbol
# MA      118
# PAYC    118
# LMT     114
# Name: LDOS, dtype: int64
# LEG Symbol
# EMN     134
# ETN     134
# APTV    132
# Name: LEG, dtype: int64
# LEN Symbol
# PHM    134
# DHI    126
# NVR     84
# Name: LEN, dtype: int64
# LH Symbol
# DGX     132
# PFE     102
# CERN     98
# Name: LH, dtype: int64
# LHX Symbol
# NOC     114
# LMT     106
# LDOS     84
# Name: LHX, dtype: int64
# LIN Symbol
# APD    118
# PPG    106
# SHW    106
# Name: LIN, dtype: int64
# LKQ Symbol
# TEL    122
# APH    120
# CE     120
# Name: LKQ, dtype: int64
# LLY Symbol
# MRK    108
# ZTS     98
# A       90
# Name: LLY, dtype: int64
# LMT Symbol
# NOC     164
# LDOS    114
# LHX     106
# Name: LMT, dtype: int64
# LNC Symbol
# PBCT    146
# DFS     140
# PRU     140
# Name: LNC, dtype: int64
# LNT Symbol
# CMS    184
# WEC    162
# XEL    162
# Name: LNT, dtype: int64
# LOW Symbol
# HD     138
# TJX    122
# GPC    120
# Name: LOW, dtype: int64
# LRCX Symbol
# AMAT    148
# KLAC    136
# MU      136
# Name: LRCX, dtype: int64
# LUV Symbol
# UAL     112
# BA       94
# TROW     94
# Name: LUV, dtype: int64
# LVS Symbol
# WYNN    134
# EMN     120
# ITW     118
# Name: LVS, dtype: int64
# LW Symbol
# LDOS    60
# MKC     60
# CPB     58
# Name: LW, dtype: int64
# LYB Symbol
# EMN    148
# URI    132
# BWA    128
# Name: LYB, dtype: int64
# LYV Symbol
# ANSS    108
# LDOS     96
# TDG      96
# Name: LYV, dtype: int64
# MA Symbol
# V       186
# PAYX    144
# ACN     140
# Name: MA, dtype: int64
# MAA Symbol
# AIV    148
# PLD    148
# EQR    146
# Name: MAA, dtype: int64
# MAR Symbol
# HLT    132
# CCL    122
# BLK    118
# Name: MAR, dtype: int64
# MAS Symbol
# DOV     128
# SWK     124
# FBHS    116
# Name: MAS, dtype: int64
# MCD Symbol
# CB      88
# MKTX    88
# HIG     80
# Name: MCD, dtype: int64
# MCHP Symbol
# MXIM    152
# ADI     148
# TXN     148
# Name: MCHP, dtype: int64
# MCK Symbol
# ABC    136
# CAH    124
# CVS    108
# Name: MCK, dtype: int64
# MCO Symbol
# SPGI    146
# VRSN    128
# MSFT    124
# Name: MCO, dtype: int64
# MDLZ Symbol
# CL     110
# CB     106
# KMB    104
# Name: MDLZ, dtype: int64
# MDT Symbol
# SYK    134
# ABT    112
# BSX    108
# Name: MDT, dtype: int64
# MET Symbol
# DFS    150
# GL     138
# LNC    136
# Name: MET, dtype: int64
# MGM Symbol
# URI     118
# CCL     114
# WYNN    112
# Name: MGM, dtype: int64
# MHK Symbol
# WHR     114
# PCAR    110
# SWK     110
# Name: MHK, dtype: int64
# MKC Symbol
# CHD     104
# HSY     104
# LDOS     84
# Name: MKC, dtype: int64
# MKTX Symbol
# MA     104
# GPN     98
# WM      98
# Name: MKTX, dtype: int64
# MLM Symbol
# VMC     140
# LDOS     82
# EFX      80
# Name: MLM, dtype: int64
# MMC Symbol
# AJG     142
# WLTW    134
# AON     126
# Name: MMC, dtype: int64
# MMM Symbol
# FLS    146
# ROK    142
# ETN    140
# Name: MMM, dtype: int64
# MNST Symbol
# EL     84
# NSC    80
# GPN    78
# Name: MNST, dtype: int64
# MO Symbol
# PM      70
# VAR     70
# ALGN    60
# Name: MO, dtype: int64
# MOS Symbol
# CAT    116
# CF     112
# EMN    112
# Name: MOS, dtype: int64
# MPC Symbol
# HFC    124
# VLO    114
# PSX    112
# Name: MPC, dtype: int64
# MRK Symbol
# DHR    114
# ZTS    114
# TFX    112
# Name: MRK, dtype: int64
# MRO Symbol
# EOG    142
# NBL    140
# DVN    134
# Name: MRO, dtype: int64
# MS Symbol
# C      158
# BAC    154
# GS     152
# Name: MS, dtype: int64
# MSCI Symbol
# SPGI    132
# V       118
# MA      112
# Name: MSCI, dtype: int64
# MSFT Symbol
# V      152
# MA     138
# ACN    134
# Name: MSFT, dtype: int64
# MSI Symbol
# LMT    96
# MMC    96
# EFX    92
# Name: MSI, dtype: int64
# MTB Symbol
# PNC    152
# KEY    140
# C      138
# Name: MTB, dtype: int64
# MTD Symbol
# TMO    126
# PKI    120
# APH    114
# Name: MTD, dtype: int64
# MU Symbol
# WDC     150
# LRCX    136
# NVDA    130
# Name: MU, dtype: int64
# MXIM Symbol
# TXN     154
# MCHP    152
# ADI     136
# Name: MXIM, dtype: int64
# MYL Symbol
# DOV     100
# PRGO     98
# A        96
# Name: MYL, dtype: int64
# NBL Symbol
# MRO    140
# DVN    134
# EOG    132
# Name: NBL, dtype: int64
# NCLH Symbol
# RCL    140
# CCL    136
# ITW    126
# Name: NCLH, dtype: int64
# NDAQ Symbol
# ICE    132
# MA     106
# CME     96
# Name: NDAQ, dtype: int64
# NEE Symbol
# LNT    160
# CMS    156
# AEP    152
# Name: NEE, dtype: int64
# NEM Symbol
# SRE    72
# AEP    66
# XEL    64
# Name: NEM, dtype: int64
# NFLX Symbol
# ORCL    86
# AMD     84
# HLT     82
# Name: NFLX, dtype: int64
# NI Symbol
# DTE    132
# FE     126
# AEE    120
# Name: NI, dtype: int64
# NKE Symbol
# VFC    116
# HIG    114
# ACN    110
# Name: NKE, dtype: int64
# NLSN Symbol
# NWSA    88
# FDX     84
# ZION    84
# Name: NLSN, dtype: int64
# NOC Symbol
# LMT     164
# LHX     114
# LDOS    110
# Name: NOC, dtype: int64
# NOV Symbol
# SLB    122
# HAL    116
# HP     108
# Name: NOV, dtype: int64
# NOW Symbol
# PAYC    156
# ADBE    138
# ANSS    128
# Name: NOW, dtype: int64
# NRG Symbol
# ATO    84
# ED     82
# D      72
# Name: NRG, dtype: int64
# NSC Symbol
# UNP    138
# CSX    126
# RTX    120
# Name: NSC, dtype: int64
# NTAP Symbol
# TROW    128
# HPE     124
# LKQ     120
# Name: NTAP, dtype: int64
# NTRS Symbol
# BAC    138
# KEY    134
# BK     130
# Name: NTRS, dtype: int64
# NUE Symbol
# EMN    126
# CAT    124
# ETN    124
# Name: NUE, dtype: int64
# NVDA Symbol
# AMAT    132
# ETN     130
# MU      130
# Name: NVDA, dtype: int64
# NVR Symbol
# DHI    92
# LEN    84
# PHM    78
# Name: NVR, dtype: int64
# NWL Symbol
# DOV    90
# WRK    84
# NUE    78
# Name: NWL, dtype: int64
# NWS Symbol
# NWSA    182
# TEL     104
# APTV     98
# Name: NWS, dtype: int64
# NWSA Symbol
# NWS     182
# APTV    112
# BWA     112
# Name: NWSA, dtype: int64
# O Symbol
# EQR    138
# ESS    134
# UDR    134
# Name: O, dtype: int64
# ODFL Symbol
# EXPD    140
# APH     120
# LEG     120
# Name: ODFL, dtype: int64
# OKE Symbol
# WMB    144
# DVN    128
# EOG    118
# Name: OKE, dtype: int64
# OMC Symbol
# IPG      144
# INTC     112
# CMCSA    110
# Name: OMC, dtype: int64
# ORCL Symbol
# IBM     106
# INTC    100
# UNM     100
# Name: ORCL, dtype: int64
# ORLY Symbol
# AZO    120
# GPC     86
# ROL     84
# Name: ORLY, dtype: int64
# OXY Symbol
# DVN    118
# EOG    114
# MRO    108
# Name: OXY, dtype: int64
# PAYC Symbol
# NOW     156
# ADBE    130
# INTU    124
# Name: PAYC, dtype: int64
# PAYX Symbol
# MA     144
# V      132
# ADP    124
# Name: PAYX, dtype: int64
# PBCT Symbol
# RF      152
# LNC     146
# FITB    144
# Name: PBCT, dtype: int64
# PCAR Symbol
# ITW    146
# BWA    140
# ROK    140
# Name: PCAR, dtype: int64
# PEAK Symbol
# VTR     140
# WELL    128
# O       122
# Name: PEAK, dtype: int64
# PEG Symbol
# SRE    128
# XEL    122
# WEC    120
# Name: PEG, dtype: int64
# PEP Symbol
# PG    116
# CL    112
# KO    108
# Name: PEP, dtype: int64
# PFE Symbol
# TMO    114
# LH     102
# PKI    102
# Name: PFE, dtype: int64
# PFG Symbol
# DFS    136
# LNC    132
# BLK    130
# Name: PFG, dtype: int64
# PG Symbol
# CL     138
# KMB    120
# PEP    116
# Name: PG, dtype: int64
# PGR Symbol
# CB     98
# MA     94
# AJG    92
# Name: PGR, dtype: int64
# PH Symbol
# EMR    162
# URI    162
# ITW    160
# Name: PH, dtype: int64
# PHM Symbol
# LEN    134
# DHI    100
# NVR     78
# Name: PHM, dtype: int64
# PKG Symbol
# WRK     138
# IP      134
# NTRS    112
# Name: PKG, dtype: int64
# PKI Symbol
# TMO    142
# A      132
# DOV    120
# Name: PKI, dtype: int64
# PLD Symbol
# AVB    148
# MAA    148
# DRE    134
# Name: PLD, dtype: int64
# PM Symbol
# MO     70
# VZ     70
# APH    66
# Name: PM, dtype: int64
# PNC Symbol
# FITB    160
# BAC     158
# COF     154
# Name: PNC, dtype: int64
# PNR Symbol
# ITW    140
# RTX    136
# PH     134
# Name: PNR, dtype: int64
# PNW Symbol
# AEP    150
# LNT    150
# WEC    148
# Name: PNW, dtype: int64
# PPG Symbol
# HON    146
# ITW    130
# DOV    126
# Name: PPG, dtype: int64
# PPL Symbol
# AEP    90
# PEG    82
# FE     80
# Name: PPL, dtype: int64
# PRGO Symbol
# RF      106
# MYL      98
# NTRS     96
# Name: PRGO, dtype: int64
# PRU Symbol
# LNC    140
# MET    134
# COF    130
# Name: PRU, dtype: int64
# PSA Symbol
# EXR    124
# AWK    104
# AMT    102
# Name: PSA, dtype: int64
# PSX Symbol
# HFC    116
# VLO    116
# MPC    112
# Name: PSX, dtype: int64
# PVH Symbol
# EMN     126
# ROK     122
# IPGP    120
# Name: PVH, dtype: int64
# PWR Symbol
# XYL    116
# SWK    106
# URI    106
# Name: PWR, dtype: int64
# PXD Symbol
# EOG    144
# DVN    142
# XOM    140
# Name: PXD, dtype: int64
# PYPL Symbol
# FLT    128
# V      128
# MA     122
# Name: PYPL, dtype: int64
# QCOM Symbol
# KLAC    110
# AMAT    108
# ETN     104
# Name: QCOM, dtype: int64
# QRVO Symbol
# MU      120
# SWKS    120
# NVDA    114
# Name: QRVO, dtype: int64
# RCL Symbol
# NCLH    140
# CCL     136
# SIVB    112
# Name: RCL, dtype: int64
# RE Symbol
# HIG    112
# WRB     98
# AIG     92
# Name: RE, dtype: int64
# REG Symbol
# FRT    158
# KIM    136
# BXP    118
# Name: REG, dtype: int64
# REGN Symbol
# ALXN    94
# AMGN    92
# VRTX    90
# Name: REGN, dtype: int64
# RF Symbol
# PBCT    152
# FITB    148
# CFG     144
# Name: RF, dtype: int64
# RHI Symbol
# APH    134
# BLK    132
# XYL    132
# Name: RHI, dtype: int64
# RJF Symbol
# LNC     130
# ETFC    124
# PRU     124
# Name: RJF, dtype: int64
# RL Symbol
# PH     128
# CAT    124
# URI    122
# Name: RL, dtype: int64
# RMD Symbol
# TFX    106
# MDT    102
# ABT    100
# Name: RMD, dtype: int64
# ROK Symbol
# ITW    144
# PH     144
# ETN    142
# Name: ROK, dtype: int64
# ROL Symbol
# AZO     86
# CSX     84
# ORLY    84
# Name: ROL, dtype: int64
# ROP Symbol
# ADBE    116
# AME     116
# HON     116
# Name: ROP, dtype: int64
# ROST Symbol
# TJX    124
# NKE    110
# LOW    104
# Name: ROST, dtype: int64
# RSG Symbol
# WM      120
# VRSK     96
# MRK      92
# Name: RSG, dtype: int64
# RTX Symbol
# PNR     136
# CSX     128
# PCAR    128
# Name: RTX, dtype: int64
# SBAC Symbol
# CCI    138
# AMT    106
# AVB     98
# Name: SBAC, dtype: int64
# SBUX Symbol
# SYK     96
# WLTW    94
# CDNS    92
# Name: SBUX, dtype: int64
# SCHW Symbol
# ETFC    134
# AMP     118
# COF     118
# Name: SCHW, dtype: int64
# SEE Symbol
# AVY    88
# PKG    76
# PKI    74
# Name: SEE, dtype: int64
# SHW Symbol
# ODFL    112
# HON     110
# CTAS    108
# Name: SHW, dtype: int64
# SIVB Symbol
# CFG     142
# PNC     140
# FITB    136
# Name: SIVB, dtype: int64
# SJM Symbol
# KMB     82
# CPB     70
# MDLZ    68
# Name: SJM, dtype: int64
# SLB Symbol
# HAL    168
# DVN    142
# EOG    136
# Name: SLB, dtype: int64
# SLG Symbol
# VNO    136
# BXP    120
# FRT     92
# Name: SLG, dtype: int64
# SNA Symbol
# URI    140
# ETN    132
# EMR    130
# Name: SNA, dtype: int64
# SNPS Symbol
# CDNS    144
# MA      132
# INTU    126
# Name: SNPS, dtype: int64
# SO Symbol
# CMS    156
# LNT    152
# XEL    150
# Name: SO, dtype: int64
# SPG Symbol
# FRT    118
# REG    118
# BXP    110
# Name: SPG, dtype: int64
# SPGI Symbol
# MCO     146
# MSCI    132
# VRSN    130
# Name: SPGI, dtype: int64
# SRE Symbol
# PEG    128
# XEL    118
# AEP    116
# Name: SRE, dtype: int64
# STE Symbol
# SYK    116
# COO    100
# ABT     92
# Name: STE, dtype: int64
# STT Symbol
# GS     130
# MS     126
# DFS    124
# Name: STT, dtype: int64
# STX Symbol
# CMI    120
# GM     114
# HPE    114
# Name: STX, dtype: int64
# STZ Symbol
# BR      80
# AKAM    74
# TAP     74
# Name: STZ, dtype: int64
# SWK Symbol
# ITW    138
# CMI    136
# DOV    134
# Name: SWK, dtype: int64
# SWKS Symbol
# MCHP    140
# MXIM    126
# QRVO    120
# Name: SWKS, dtype: int64
# SYF Symbol
# DFS     120
# LNC     116
# TROW    112
# Name: SYF, dtype: int64
# SYK Symbol
# ABT    144
# MDT    134
# BSX    122
# Name: SYK, dtype: int64
# SYY Symbol
# VZ     76
# NKE    74
# PG     74
# Name: SYY, dtype: int64
# T Symbol
# TMUS    96
# ACN     84
# HPE     82
# Name: T, dtype: int64
# TAP Symbol
# L      116
# PFG    106
# HOG     92
# Name: TAP, dtype: int64
# TDG Symbol
# RTX    116
# V      116
# AON    114
# Name: TDG, dtype: int64
# TEL Symbol
# IPGP    142
# APH     138
# EXPD    136
# Name: TEL, dtype: int64
# TFC Symbol
# MTB     136
# FITB    134
# BAC     128
# Name: TFC, dtype: int64
# TFX Symbol
# SYK     120
# MRK     112
# IDXX    108
# Name: TFX, dtype: int64
# TGT Symbol
# MMM    88
# DG     82
# VFC    82
# Name: TGT, dtype: int64
# TIF Symbol
# RHI    110
# BLK    106
# LVS    102
# Name: TIF, dtype: int64
# TJX Symbol
# ROST    124
# LOW     122
# COST    106
# Name: TJX, dtype: int64
# TMO Symbol
# PKI    142
# A      136
# DHR    128
# Name: TMO, dtype: int64
# TMUS Symbol
# T      96
# VZ     86
# GPC    84
# Name: TMUS, dtype: int64
# TPR Symbol
# PH     120
# ITW    118
# PNR    112
# Name: TPR, dtype: int64
# TROW Symbol
# BLK     134
# COF     128
# NTAP    128
# Name: TROW, dtype: int64
# TRV Symbol
# CB      134
# CINF    122
# HIG     110
# Name: TRV, dtype: int64
# TSCO Symbol
# CPRT    84
# UNP     82
# DFS     80
# Name: TSCO, dtype: int64
# TSN Symbol
# APD    82
# BLL    80
# MA     78
# Name: TSN, dtype: int64
# TTWO Symbol
# SNPS    84
# CCI     82
# FIS     78
# Name: TTWO, dtype: int64
# TWTR Symbol
# VRSN    106
# ZTS      98
# AMZN     92
# Name: TWTR, dtype: int64
# TXN Symbol
# MXIM    154
# MCHP    148
# ADI     140
# Name: TXN, dtype: int64
# TXT Symbol
# MMM    130
# PH     126
# BWA    124
# Name: TXT, dtype: int64
# UA Symbol
# UAA    212
# AMP    110
# BAC    108
# Name: UA, dtype: int64
# UAA Symbol
# UA     212
# AMP    118
# BAC    116
# Name: UAA, dtype: int64
# UAL Symbol
# DAL    132
# AAL    124
# LEG    122
# Name: UAL, dtype: int64
# UDR Symbol
# EQR    166
# AVB    160
# AIV    154
# Name: UDR, dtype: int64
# UHS Symbol
# DVA    94
# HCA    94
# CAH    90
# Name: UHS, dtype: int64
# ULTA Symbol
# ADP     96
# ROST    90
# FLT     86
# Name: ULTA, dtype: int64
# UNH Symbol
# ANTM    130
# CNC     128
# HUM     128
# Name: UNH, dtype: int64
# UNM Symbol
# LNC    140
# DFS    124
# PFG    124
# Name: UNM, dtype: int64
# UNP Symbol
# NSC    138
# CSX    128
# RTX    126
# Name: UNP, dtype: int64
# UPS Symbol
# FDX     138
# BLK     130
# PCAR    130
# Name: UPS, dtype: int64
# URI Symbol
# PH     162
# BLK    150
# CAT    146
# Name: URI, dtype: int64
# USB Symbol
# PNC    152
# COF    150
# BAC    144
# Name: USB, dtype: int64
# V Symbol
# MA      186
# MSFT    152
# ACN     138
# Name: V, dtype: int64
# VAR Symbol
# A      110
# TMO    106
# DHR    104
# Name: VAR, dtype: int64
# VFC Symbol
# ITW    132
# GWW    126
# GPC    122
# Name: VFC, dtype: int64
# VLO Symbol
# HFC    122
# PSX    116
# MPC    114
# Name: VLO, dtype: int64
# VMC Symbol
# MLM     140
# LDOS     86
# LMT      80
# Name: VMC, dtype: int64
# VNO Symbol
# BXP    148
# SLG    136
# FRT    126
# Name: VNO, dtype: int64
# VRSK Symbol
# INFO    114
# PAYX    114
# CTAS    110
# Name: VRSK, dtype: int64
# VRSN Symbol
# MSFT    132
# SPGI    130
# MCO     128
# Name: VRSN, dtype: int64
# VRTX Symbol
# ALXN    100
# INCY     90
# PKI      90
# Name: VRTX, dtype: int64
# VTR Symbol
# PEAK    140
# WELL    128
# AIV     100
# Name: VTR, dtype: int64
# VZ Symbol
# TMUS    86
# WLTW    84
# CB      82
# Name: VZ, dtype: int64
# WAB Symbol
# MMM    120
# ITW    112
# XRX    110
# Name: WAB, dtype: int64
# WAT Symbol
# A      132
# TMO    118
# MTD    112
# Name: WAT, dtype: int64
# WBA Symbol
# CAH    98
# CVS    94
# ABC    90
# Name: WBA, dtype: int64
# WDC Symbol
# MU      150
# GM      120
# MXIM    120
# Name: WDC, dtype: int64
# WEC Symbol
# AEP    164
# CMS    164
# XEL    164
# Name: WEC, dtype: int64
# WELL Symbol
# PEAK    128
# VTR     128
# AIV     126
# Name: WELL, dtype: int64
# WFC Symbol
# BAC    128
# USB    128
# COF    126
# Name: WFC, dtype: int64
# WHR Symbol
# SWK     128
# MHK     114
# FBHS    106
# Name: WHR, dtype: int64
# WLTW Symbol
# MMC    134
# AJG    126
# AON    118
# Name: WLTW, dtype: int64
# WM Symbol
# RSG    120
# CL     114
# CB     108
# Name: WM, dtype: int64
# WMB Symbol
# OKE    144
# EOG    108
# XOM    106
# Name: WMB, dtype: int64
# WMT Symbol
# ORLY    78
# DG      74
# GOOG    74
# Name: WMT, dtype: int64
# WRB Symbol
# CINF    124
# TRV     106
# CB      104
# Name: WRB, dtype: int64
# WRK Symbol
# IP     142
# PKG    138
# DOV    112
# Name: WRK, dtype: int64
# WU Symbol
# RTX      88
# GOOGL    86
# DIS      82
# Name: WU, dtype: int64
# WY Symbol
# URI    102
# BLK     98
# SWK     98
# Name: WY, dtype: int64
# WYNN Symbol
# URI    136
# LVS    134
# EMN    132
# Name: WYNN, dtype: int64
# XEL Symbol
# CMS    174
# AEP    166
# WEC    164
# Name: XEL, dtype: int64
# XLNX Symbol
# INTC    120
# MCHP    120
# MXIM    114
# Name: XLNX, dtype: int64
# XOM Symbol
# DVN    146
# PXD    140
# CVX    136
# Name: XOM, dtype: int64
# XRAY Symbol
# HSIC    82
# COO     72
# HOLX    72
# Name: XRAY, dtype: int64
# XRX Symbol
# GM      118
# HPE     118
# NTAP    112
# Name: XRX, dtype: int64
# XYL Symbol
# ROK    138
# RHI    132
# FTV    124
# Name: XYL, dtype: int64
# YUM Symbol
# VRSK    84
# AJG     82
# CTAS    78
# Name: YUM, dtype: int64
# ZBH Symbol
# SYK    120
# ABT    112
# EW     104
# Name: ZBH, dtype: int64
# ZBRA Symbol
# AME    112
# CDW    102
# ETN    102
# Name: ZBRA, dtype: int64
# ZION Symbol
# CFG     140
# FITB    140
# CMA     136
# Name: ZION, dtype: int64
# ZTS Symbol
# CTAS    118
# IDXX    116
# MRK     114
# Name: ZTS, dtype: int64
